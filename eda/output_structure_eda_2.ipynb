# %% [markdown]
# # Output 문장 구조 EDA

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Obtaining dependency information for nltk from https://files.pythonhosted.org/packages/a6/0a/0d20d2c0f16be91b9fa32a77b76c60f9baf6eba419e5ef5deca17af9c582/nltk-3.8.1-py3-none-any.whl.metadata
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: click in c:\users\user\anaconda3\envs\nlp1\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\envs\nlp1\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\envs\nlp1\lib\site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\envs\nlp1\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\nlp1\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.5 MB 660.6 kB/s eta 0:00:03
#    ----------- ---------------------------- 0.4/1.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 12.0 MB/s eta 0:00:00
# Installing collected packages: nltk
# Successfully installed nltk-3.8.1

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
from copy import deepcopy
from transformers import AutoTokenizer
from collections import defaultdict
from nltk import ngrams

# %%
def make_dataframe(path: str) -> pd.DataFrame:
    """
    Read a json file and return a pandas DataFrame.

    Parameters:
    path (str): Path to the json file.

    Returns:
    pd.DataFrame: DataFrame of the json file.
    """
    # Read the json file
    with open(path, 'r') as file:
        data = json.load(file)

    # Create a DataFrame
    # columns = ['id', 'conversation', 'subject_keyword', 'output']
    df = pd.DataFrame(data)
    df['conversation'] = df['input'].apply(lambda x: x['conversation'])
    df['subject_keyword'] = df['input'].apply(lambda x: x['subject_keyword'])

    # Drop the 'input' column
    df.drop('input', axis=1, inplace=True)

    # Speakers in the conversation
    df['speakers'] = df['conversation'].apply(lambda turns: list(set(turn['speaker'] for turn in turns)))

    # Reorder the columns
    try:
        df = df[['id', 'conversation', 'subject_keyword', 'speakers', 'output','inference']]

    except:
        df = df[['id', 'conversation', 'subject_keyword', 'speakers', 'output']]

    return df

# %%
# train_df = make_dataframe('../resource/data/일상대화요약_train.json')
# dev_df = make_dataframe('../resource/data/일상대화요약_dev.json')
# test_df = make_dataframe('../resource/data/일상대화요약_test.json')
train_df = make_dataframe('./train.json')
dev_df = make_dataframe('./dev.json')
test_df = make_dataframe('./test.json')

# %%
nova_result = make_dataframe('../results/hypernova.json')
dev_nova_result = make_dataframe('../results/hypernova_dev.json')
hypernova_result = make_dataframe('../results/hypernova.json')
supernova_reuslt = make_dataframe('../results/supernova3.json')

# %% [markdown]
# ## 전반적인 요약 유형

# %% [markdown]
# - 맨 앞 전반적인 요약 부분은 어떤 유형의 문장이 있는지 확인

# %%
from nltk.util import ngrams

def find_common_ngrams(df, n):

    sentences = df['output'].apply(lambda x: x.split('.')[0])

    def preprocess(sentence):
        return sentence.split()

    ngrams_list = []
    total_ngrams_set = set()
    total_ngrams_dict = defaultdict(int)
    
    for sentence in sentences:
        tokens = preprocess(sentence)
        ngrams_list.append(list(ngrams(tokens, n)))
    

    # 같은 n-gram이 나타나는 문장을 찾기
    for i in range(len(ngrams_list)-1):
        common_ngrams = set(ngrams_list[i])
        
        for ngrams_set in ngrams_list[i+1:]:
            total_ngrams_set.update(common_ngrams.intersection(ngrams_set))

    # n-gram이 나타나는 문장의 개수 세기
    for common_ngram in total_ngrams_set:
        for ngrams_set in ngrams_list:
            if common_ngram in ngrams_set:
                total_ngrams_dict[common_ngram] += 1

    # 정렬
    total_ngrams_dict = dict(sorted(total_ngrams_dict.items(), key=lambda x: x[1], reverse=True))
    
    return total_ngrams_dict

# %%
common_ngrams = find_common_ngrams(train_df, 4)
# for ngram in common_ngrams:
#     print(' '.join(ngram))
common_ngrams
# Out:
# {('두', '화자는', '이', '대화에서'): 152,
#  ('이', '대화에서', '두', '화자는'): 7,
#  ('이', '대화에서', '화자들은', '좋아하는'): 7,
#  ('화자는', '이', '대화에서', '좋아하는'): 6,
#  ('이', '대화에서', '화자들은', '기억에'): 4,
#  ('화자는', '이', '대화에서', '기억에'): 4,
#  ('이', '대화에서', '기억에', '남는'): 4,
#  ('대화에서', '화자들은', '기억에', '남는'): 4,
#  ('이', '대화에서', 'SD2100585와', 'SD2100586은'): 4,
#  ('화자는', '이', '대화에서', '건강'): 4,
#  ('이', '대화에서', '인상', '깊었던'): 3,
#  ('두', '사람은', '기억에', '남는'): 3,
#  ('화자는', '이', '대화에서', '자신의'): 3,
#  ('이', '대화에서', '화자들은', '요즘'): 3,
#  ('대화에서', '화자', 'SD2100517과', 'SD2100518은'): 3,
#  ('화자는', '이', '대화에서', '자녀의'): 3,
#  ('이', '대화에서', '화자들은', '운동에'): 3,
#  ('화자는', '이', '대화에서', '영화'): 3,
#  ('음식에', '관한', '대화를', '나눴습니다'): 3,
#  ('이', '대화에서', '화자들은', '선호하는'): 3,
#  ('싶은', '선물에', '대해', '말했습니다'): 3,
#  ('이', '대화에서', '화자', 'SD2100517과'): 3,
#  ('가고', '싶은', '여행지에', '대해'): 3,
#  ('받고', '싶은', '선물에', '대해'): 3,
#  ('화자들은', '운동에', '대해', '이야기했습니다'): 3,
#  ('이', '대화에서', '화자들은', '건강'): 3,
#  ('화자는', '이', '대화에서', '아르바이트'): 3,
#  ('대화에서', '화자들은', '운동에', '대해'): 3,
#  ('화자는', '이', '대화에서', '인상'): 3,
#  ('화자는', '이', '대화에서', '여행'): 3,
#  ('아르바이트와', '하고', '싶은', '아르바이트에'): 2,
#  ('화자들은', '선호하는', '음식에', '대해'): 2,
#  ('기억에', '남는', '선물과', '받고'): 2,
#  ('수상', '레저에', '대해', '이야기했습니다'): 2,
#  ('대화에서', '화자', 'SD2100515와', 'SD2100516은'): 2,
#  ('스타일에', '대해', '이야기를', '나눴습니다'): 2,
#  ('두', '사람은', '자주', '보는'): 2,
#  ('여행', '스타일에', '대해', '이야기했습니다'): 2,
#  ('대화에서', '화자', 'SD2002290과', 'SD2002291은'): 2,
#  ('경험에', '대해', '대화를', '나눴습니다'): 2,
#  ('국내', '여행지에', '대해', '이야기했습니다'): 2,
#  ('이', '대화에서', 'SD2002331과', 'SD2002394는'): 2,
#  ('이', '대화에서', '자녀의', '꿈에'): 2,
#  ('선호하는', '여행', '스타일에', '대해'): 2,
#  ('이', '대화에서', '화자', 'SD2000988과'): 2,
#  ('이', '대화에서', 'SD2100583과', 'SD2100584는'): 2,
#  ('SD2100524와', 'SD2110523은', '티브이', '프로그램에'): 2,
#  ('대화에서', '화자', 'SD2001085와', 'SD2001086은'): 2,
#  ('대화에서', '화자', 'SD2001968와', 'SD2001969는'): 2,
#  ('방송', '프로그램에', '관한', '대화를'): 2,
#  ('화자는', '이', '대화에서', '키우고'): 2,
#  ('방법에', '대해', '이야기를', '나눴습니다'): 2,
#  ('여행지에서의', '음식에', '관한', '대화를'): 2,
#  ('선물과', '받고', '싶은', '선물에'): 2,
#  ('선호하는', '음식에', '대해', '이야기했습니다'): 2,
#  ('경험에', '대한', '이야기를', '나눴습니다'): 2,
#  ('꿈과', '목표에', '대해', '이야기했습니다'): 2,
#  ('이', '대화에서', '화자들은', '풋살'): 2,
#  ('싶은', '여행지에', '대해', '이야기했습니다'): 2,
#  ('화자', 'SD2000988과', '화자', 'SD2000989는'): 2,
#  ('이', '대화에서', '화자', 'SD2100515와'): 2,
#  ('화자는', '이', '대화에서', '선물을'): 2,
#  ('이', '대화에서', '화자들은', '음악'): 2,
#  ('대화에서', '화자', 'SD2100516과', 'SD2100515는'): 2,
#  ('이', '대화에서', '화자들은', '반려동물'): 2,
#  ('화자는', '이', '대화에서', '하고'): 2,
#  ('자신의', '성격에', '대해', '이야기했습니다'): 2,
#  ('가보고', '싶은', '여행지에', '대해'): 2,
#  ('대화에서', '화자', 'SD2001966와', 'SD2001967은'): 2,
#  ('대화에서', 'SD2002331과', 'SD2002394는', '영화를'): 2,
#  ('쇼핑하는', '방법에', '대해', '이야기했습니다'): 2,
#  ('듣는', '음악에', '대해', '이야기했습니다'): 2,
#  ('장르에', '대해', '이야기를', '나눴습니다'): 2,
#  ('프로그램에', '관한', '대화를', '나눴습니다'): 2,
#  ('SD2110523은', '티브이', '프로그램에', '대해'): 2,
#  ('화자는', '이', '대화에서', '추천하고'): 2,
#  ('화자', 'SD2100524와', 'SD2110523은', '티브이'): 2,
#  ('여행지에', '대해', '대화를', '나눴습니다'): 2,
#  ('화자는', '이', '대화에서', '결혼과'): 2,
#  ('화자들은', '맛집에', '대해', '이야기했습니다'): 2,
#  ('두', '사람은', '여행에', '관한'): 2,
#  ('이', '대화에서', '화자', 'SD2001081과'): 2,
#  ('선물에', '관한', '대화를', '나눴습니다'): 2,
#  ('이', '대화에서', 'SD2002049와', 'SD2002050은'): 2,
#  ('관계에', '대해', '대화를', '나눴습니다'): 2,
#  ('대화에서', '자녀의', '꿈에', '대해'): 2,
#  ('대화에서', '화자', 'SD2001104와', 'SD2001105는'): 2,
#  ('이', '대화에서', '화자', 'SD2100516과'): 2,
#  ('화자는', '이', '대화에서', '최근'): 2,
#  ('이', '대화에서', '화자', 'SD2002290과'): 2,
#  ('이', '대화에서', '화자들은', '계절과'): 2,
#  ('관련', '고민에', '대해', '이야기했습니다'): 2,
#  ('기억에', '남는', '여행지에', '대해'): 2,
#  ('화자는', '이', '대화에서', '가족의'): 2,
#  ('여행지에', '관한', '대화를', '나눴습니다'): 2,
#  ('음식과', '요리에', '대해', '이야기했습니다'): 2,
#  ('여행에', '관한', '대화를', '했습니다'): 2,
#  ('이', '대화에서', '화자', 'SD2100524와'): 2,
#  ('진로', '관련', '고민에', '대해'): 2,
#  ('건강', '관리에', '대해', '말했습니다'): 2,
#  ('이', '대화에서', 'SD2100003과', 'SD2100004는'): 2,
#  ('대화에서', '화자', 'SD2000894와', 'SD2000895는'): 2,
#  ('화자는', '이', '대화에서', '선호하는'): 2,
#  ('자신', '있는', '요리에', '대해'): 2,
#  ('두', '사람은', '투자에', '대해'): 2,
#  ('사람은', '여행에', '관한', '대화를'): 2,
#  ('이', '대화에서', 'SD2002075와', 'SD2002076은'): 2,
#  ('화자는', '이', '대화에서', '엠비티아이'): 2,
#  ('대화에서', '화자', 'SD2001081과', 'SD2001083은'): 2,
#  ('영화', '관람', '스타일에', '대해'): 2,
#  ('이', '대화에서', '여행', '계획,'): 2,
#  ('이', '대화에서', '화자', 'SD2001966와'): 2,
#  ('화자들은', '가고', '싶은', '여행지와'): 2,
#  ('이', '대화에서', '화자', 'SD2000894와'): 2,
#  ('자녀의', '꿈에', '대해', '말했습니다'): 2,
#  ('이', '대화에서', 'SD2100005와', 'SD2100006은'): 2,
#  ('대화에서', '화자', 'SD2100524와', 'SD2110523은'): 2,
#  ('이', '대화에서', '추천하고', '싶은'): 2,
#  ('이', '대화에서', '아르바이트', '경험과'): 2,
#  ('대화에서', '화자', 'SD2000988과', '화자'): 2,
#  ('음식에', '관한', '대화를', '했습니다'): 2,
#  ('티브이', '프로그램에', '대해', '이야기했습니다'): 2,
#  ('대화에서', '화자들은', '계절과', '날씨에'): 2,
#  ('이', '대화에서', '화자', 'SD2001104와'): 2,
#  ('이', '대화에서', '화자들은', '여행'): 2,
#  ('기억에', '남는', '일화에', '대해'): 2,
#  ('꿈과', '목표에', '대해', '말했습니다'): 2,
#  ('중', '기억에', '남는', '일화에'): 2,
#  ('남는', '선물과', '받고', '싶은'): 2,
#  ('싶은', '여행지에', '대해', '말했습니다'): 2,
#  ('이', '대화에서', '키우고', '싶은'): 2,
#  ('이', '대화에서', '화자', 'SD2001968와'): 2,
#  ('이', '대화에서', '화자들은', '다이어트'): 2,
#  ('이', '대화에서', '화자들은', '좋았던'): 2,
#  ('화자는', '이', '대화에서', '받고'): 2,
#  ('이', '대화에서', '화자들은', '가족'): 2,
#  ('이', '대화에서', '화자', 'SD2001085와'): 2,
#  ('이', '대화에서', '선물에', '대한'): 2,
#  ('화자는', '이', '대화에서', '운동과'): 2,
#  ('있는', '요리에', '대해', '말했습니다'): 2,
#  ('화자는', '이', '대화에서', '선물에'): 2,
#  ('이', '대화에서', 'SD2002605와', 'SD2002606은'): 2,
#  ('사람은', '투자에', '대해', '대화했습니다'): 2,
#  ('이', '대화에서', '화자들은', '코로나'): 2,
#  ('가고', '싶은', '여행지와', '여행'): 2,
#  ('화자는', '이', '대화에서', '현재'): 2,
#  ('화자들은', '쇼핑하는', '방법에', '대해'): 2,
#  ('화자', 'SD2001966와', 'SD2001967은', '추천하는'): 2,
#  ('화자는', '이', '대화에서', '다이어트'): 2}

# %%
common_ngrams = find_common_ngrams(dev_df, 4)
common_ngrams
# Out:
# {('두', '화자는', '이', '대화에서'): 54,
#  ('이', '대화에서', '두', '화자는'): 8,
#  ('화자는', '이', '대화에서', '좋아하는'): 5,
#  ('이', '대화에서', '화자들은', '좋아하는'): 4,
#  ('두', '사람은', '이', '대화에서'): 4,
#  ('화자는', '이', '대화에서', '건강'): 4,
#  ('이', '대화에서', '선물에', '대해'): 3,
#  ('화자는', '이', '대화에서', '학교생활에'): 3,
#  ('대화에서', '선물에', '대해', '말했습니다'): 3,
#  ('화자는', '이', '대화에서', '학교'): 3,
#  ('화자는', '이', '대화에서', '선물에'): 3,
#  ('대화에서', '학교', '생활에', '대해'): 2,
#  ('학교', '생활에', '대해', '말했습니다'): 2,
#  ('관리와', '운동에', '대해', '말했습니다'): 2,
#  ('이', '대화에서', '학교생활에', '대해'): 2,
#  ('이', '대화에서', '화자들은', '가족'): 2,
#  ('아르바이트에', '대해', '이야기를', '나눴습니다'): 2,
#  ('화자는', '이', '대화에서', '결혼과'): 2,
#  ('이', '대화에서', '학교', '생활에'): 2,
#  ('화자는', '이', '대화에서', '현재'): 2,
#  ('대화에서', '학교생활에', '대해', '말했습니다'): 2,
#  ('대화에서', '두', '화자는', '좋아하는'): 2}

# %%
import re

def find_another_type_total_summary(df):
    types = ["두 화자는 이 대화에서", "두 화자는", "화자들은" ,"두 사람은", "이 대화에서는"]
    types2 = r"SD\d{7}(?:와|과).*SD\d{7}(?:은|는)"# r".+[과와].+[은는]"
    cnt = 0

    sentences = df['output'].apply(lambda x: x.split('.')[0] if x.split('.')[1] else print(x))

    for sentence in sentences:
        yes = 0
        for type in types:
            if type in sentence:
                cnt += 1
                yes = 1
                break
            elif re.search(types2, sentence):
                cnt += 1
                yes = 1
                break

        if yes==0:

            print(sentence)

    print(cnt)

# %%
find_another_type_total_summary(train_df)
# Out:
# 이 대화에서 화자 SD2000875는 진로에 대한 고민을 이야기했고 화자SD2000873은 공감과 조언을 통한 상담을 해주었습니다
# SD2100525는 가끔씩 밖에 나가거나 비가 온 후 냄새가 좋아서 자주 나가야겠다는 생각을 했으며 땀이 날 정도로 운동을 해야 한다는 의사 선생님의 말씀을 듣고 한동안 열심히 운동을 했다가 요즘 뱃살이 많아져서 너무 스트레스를 받는다고 이야기했습니다
# 504

# %%
find_another_type_total_summary(dev_df)
# Out:
# 이 대화에서 가장 인상 깊었던 여행지와 추천하고 싶은 여행지를 공유했습니다
# SD2000862는 엔시티의 보스 착장 중 제복 착장이 멤버들의 피지컬 덕분에 좋았고 터프하게 랩을 하는 마크의 모습이 인상깊었다고 말했습니다
# 100

# %% [markdown]
# ## 유형은 총 6가지
#
# - "두 화자는 이 대화에서"
# - "두 화자는"
# - "화자들은"
# - "두 사람은"
# - "이 대화에서는"
# - r".+[과와].+[은는]"

# %% [markdown]
# - 본 유형에 해당하지 않는 샘플이 train에서 2개, dev에서 2개 존재
#     - 이 경우는 같은 speaker에 해당하는 샘플(주변 샘플)에서 '전반적인 요약'에 해당하는 부분을 온전히 얻어올 수 있었음
#     - 또는 간단한 수정을 통해 해결 가능 (이 대화에서 -> 두 화자는 이 대화에서)

# %% [markdown]
# ---
#
# - **train-000032**
#     - 이 대화에서 화자 SD2000875는 진로에 대한 고민을 이야기했고 화자SD2000873은 공감과 조언을 통한 상담을 해주었습니다 \
#         -> `"두 화자는 이 대화에서 진로 관련 고민에 대해 이야기했습니다." 로 변경`
#
# <br/>
#
# - **train-000418**
#     - 전반적인 요약이 존재하지 않아 -> 이전 샘플의 전반적인 요약을 그대로 가져옴\
#         -> `"두 화자는 이 대화에서 다이어트에 대해 이야기했습니다." 를 맨 앞 문장에 추가.` 이어서 다음 문장을 붙임
#     - SD2100525는 가끔씩 밖에 나가거나 비가 온 후 냄새가 좋아서 자주 나가야겠다는 생각을 했으며 땀이 날 정도로 운동을 해야 한다는 의사 선생님의 말씀을 듣고 한동안 열심히 운동을 했다가 요즘 뱃살이 많아져서 너무 스트레스를 받는다고 이야기했습니다
#
# <br/>
#
# - **dev-000074**
#     - `이 대화에서 -> 두 화자는 이 대화에서`
#
# - **dev-000093**
#     - 전반적인 요약이 존재하지 않아
#         - `"두 화자는 이 대화에서 엔시티와 방탄소년단에 대해 이야기 했습니다." 를 맨 앞 문장에 추가.`
#     - SD2000862는 엔시티의 보스 착장 중 제복 착장이 멤버들의 피지컬 덕분에 좋았고 터프하게 랩을 하는 마크의 모습이 인상깊었다고 말했습니다
#
# ---

# %%
# 변경 이후
train_df = make_dataframe('./train.json')
dev_df = make_dataframe('./dev.json')
test_df = make_dataframe('./test.json')

# %%
find_another_type_total_summary(train_df)
# Out:
# 506

# %%
find_another_type_total_summary(dev_df)
# Out:
# 102

# %% [markdown]
# ## 전반적인 요약 형식 통일

# %% [markdown]
# - 일단, 모든 경우 중에
#     - "두 화자는 이 대화에서" 이다
#         - train(150 + 7) / 506
#         - dev(52 + 8) / 102
#
#     - 모든 경우를 "두 화자는 이 대화에서" 방식으로 통일시켜보자
#     - 그렇다면, 모델은 '전반적인 요약'을 어떤 유형으로 답해야하는지 맞추는 것이 아닌
#
#         - 그 뒤에 해당하는 '전반적인 요약'에 해당하는 작업을 온전하게 집중할 수 있을 것이다

# %% [markdown]
# ## type1과 type2에 해당하는 경우 뒤에 SD가 들어간 sepeaker가 있는지 확인

# %%
# type1과 type2에 해당하는 경우 뒤에 SD가 들어간 sepeaker가 있는지 확인

def find_SD_after_type(df):
    types = ["두 화자는 이 대화에서", "두 화자는", "화자들은" ,"두 사람은", "이 대화에서는"]
    types2 = r"SD\d{7}(?:와|과).*SD\d{7}(?:은|는)"
    cnt = 0

    sentences = df['output'].apply(lambda x: x.split('.')[0])

    for sentence in sentences:
        for type in types:
            if type in sentence:
                match = re.search(type + r'(.*)', sentence, re.DOTALL)
                post_sentence = match.group(1).strip() 
                if 'SD' in sentence:
                    cnt += 1
                    print('post:',post_sentence)
                    print('total:',sentence)
                    print('-'*30)
                    break
            elif re.search(types2, sentence):
                match = re.search(types2 + r'(.*)', sentence, re.DOTALL)
                post_sentence = match.group(1).strip() 
                if 'SD' in post_sentence:
                    cnt += 1
                    print('post:',post_sentence)
                    print('total',sentence)
                    print('-'*30)
                    break

    print(cnt)

# %%
find_SD_after_type(train_df)
# Out:
# post: SD2000039의 꿈인 전원주택에서 살기 위한 준비 과정에 대해 이야기했습니다
# total: 두 화자는 이 대화에서 SD2000039의 꿈인 전원주택에서 살기 위한 준비 과정에 대해 이야기했습니다
# ------------------------------
# post: 애완동물을 키울 때 장단점에 대해 말했습니다 SD2001335는 반려동물 기르는 것을 선호하지 않았지만, 자녀가 너무 원해서 고양이를 기르기 시작했고 1년 정도 됐다고 말했습니다
# total: 두 화자는 이 대화에서 애완동물을 키울 때 장단점에 대해 말했습니다 SD2001335는 반려동물 기르는 것을 선호하지 않았지만, 자녀가 너무 원해서 고양이를 기르기 시작했고 1년 정도 됐다고 말했습니다
# ------------------------------
# 2

# %%
find_SD_after_type(dev_df)
# Out:
# 0

# %% [markdown]
# #### 결과
# - 506개의 train 중에 단 1개, dev는 존재하지 않음
# - 그러므로, 데이터에서
#     - 맨 앞 문장의 경우
#     - SD~~ 와 같은 speaker가 등장하는 경우는
#         - 문장 type을 맞추기 위한 경우를 제외하고는 없다
#         - 단 하나의 예외가 있을 뿐
#
#     - 예외 처리를 위해 "SD2000039의 꿈인"을 없애주자
#
# - **train-000020**
#
#     - post: SD2000039의 꿈인 전원주택에서 살기 위한 준비 과정에 대해 이야기했습니다
#     - total: 두 화자는 이 대화에서 SD2000039의 꿈인 전원주택에서 살기 위한 준비 과정에 대해 이야기했습니다
#
#         -> `"두 화자는 이 대화에서 전원주택에서 살기 위한 준비 과정에 대해 이야기했습니다" 로 변경`
#
#
# <br/>
#
# - **train-000176**
#
#     - post: 애완동물을 키울 때 장단점에 대해 말했습니다 SD2001335는 반려동물 기르는 것을 선호하지 않았지만, 자녀가 너무 원해서 고양이를 기르기 시작했고 1년 정도 됐다고 말했습니다
#     - total: 두 화자는 이 대화에서 애완동물을 키울 때 장단점에 대해 말했습니다 SD2001335는 반려동물 기르는 것을 선호하지 않았지만, 자녀가 너무 원해서 고양이를 기르기 시작했고 1년 정도 됐다고 말했습니다
#
#     - **이 경우는 맨 앞 문장에 해당하는 '전반적인 요약' 문장 맨 끝에 '.'이 없는 이상 샘플이다**
#
#         -> `'두 화자는 이 대화에서 애완동물을 키울 때 장단점에 대해 말했습니다' 뒤에 '.'를 추가`

# %% [markdown]
# - 변경 이후

# %%
# 변경 이후
train_df = make_dataframe('./train.json')
dev_df = make_dataframe('./dev.json')
test_df = make_dataframe('./test.json')

find_another_type_total_summary(train_df)
find_another_type_total_summary(dev_df)

find_SD_after_type(train_df)
find_SD_after_type(dev_df)
# Out:
# 506
# 102
# 0
# 0

# %% [markdown]
# ## type1과 type2의 앞에 있는 내용 확인

# %%
# type1과 type2을 포함하여 앞에 있는 문장 종류를 확인

def find_before_type(df):
    types = ["두 화자는 이 대화에서", "두 화자는", "화자들은" ,"두 사람은", "이 대화에서는"]
    types2 = r"SD\d{7}(?:와|과).*SD\d{7}(?:은|는)"
    cnt = 0

    sentences = df['output'].apply(lambda x: x.split('.')[0])

    for idx, sentence in enumerate(sentences):
        yes = 0
        if re.search(types2, sentence):
            match = re.search(r'(.*)'+types2, sentence, re.DOTALL)
            pre_sentence = match.group(0).strip() 
            print(f'{idx} pre:',pre_sentence)
            # print('total',sentence)
            print('-'*30)
            yes = 1
            continue
        for type in types:
            if type in sentence:
                match = re.search(r'(.*)'+type, sentence, re.DOTALL)
                pre_sentence = match.group(0).strip() 
                print(f'{idx} pre:',pre_sentence)
                # print('total:',sentence)
                print('-'*30)
                yes = 1
                break
        
        if yes==0:
            raise ValueError('No type detected')

# %%
find_before_type(train_df)
# Out:
# 0 pre: 이 대화에서 화자들은
# ------------------------------
# 1 pre: 이 대화에서 화자들은
# ------------------------------
# 2 pre: 이 대화에서 화자들은
# ------------------------------
# 3 pre: 두 화자는 이 대화에서
# ------------------------------
# 4 pre: 두 화자는 이 대화에서
# ------------------------------
# 5 pre: 두 화자는 이 대화에서
# ------------------------------
# 6 pre: 이 대화에서 화자들은
# ------------------------------
# 7 pre: 이 대화에서 화자들은
# ------------------------------
# 8 pre: 이 대화에서 화자들은
# ------------------------------
# 9 pre: 이 대화에서 화자들은
# ------------------------------
# 10 pre: 이 대화에서 화자들은
# ------------------------------
# 11 pre: 이 대화에서 화자들은
# ------------------------------
# 12 pre: 이 대화에서 화자들은
# ------------------------------
# 13 pre: 이 대화에서 화자 SD2000034와 화자 SD2000035는
# ------------------------------
# 14 pre: SD2000038과 SD2000039는
# ------------------------------
# 15 pre: SD2000038과 SD2000039는
# ------------------------------
# 16 pre: SD2000038과 SD2000039는
# ------------------------------
# 17 pre: 두 화자는 이 대화에서
# ------------------------------
# 18 pre: 두 화자는 이 대화에서
# ------------------------------
# 19 pre: 두 화자는 이 대화에서
# ------------------------------
# 20 pre: 두 화자는 이 대화에서
# ------------------------------
# 21 pre: 두 화자는 이 대화에서
# ------------------------------
# 22 pre: 두 화자는 이 대화에서
# ------------------------------
# 23 pre: SD2000042와 SD2000043은
# ------------------------------
# 24 pre: 이 대화에서 화자 SD2000042와 SD2000043은
# ------------------------------
# 25 pre: 이 대화에서 화자 SD2000044와 SD2000045는
# ------------------------------
# 26 pre: 두 화자는 이 대화에서
# ------------------------------
# 27 pre: SD2000871과 SD2000872는
# ------------------------------
# 28 pre: SD2000871과 SD2000872는
# ------------------------------
# 29 pre: 두 화자는 이 대화에서
# ------------------------------
# 30 pre: 두 화자는 이 대화에서
# ------------------------------
# 31 pre: 두 화자는 이 대화에서
# ------------------------------
# 32 pre: 이 대화에서 화자들은
# ------------------------------
# 33 pre: 이 대화에서 화자들은
# ------------------------------
# 34 pre: 이 대화에서 화자들은
# ------------------------------
# 35 pre: 두 화자는 이 대화에서
# ------------------------------
# 36 pre: 두 화자는 이 대화에서
# ------------------------------
# 37 pre: SD2000880과 SD2000881은
# ------------------------------
# 38 pre: SD2000880과 SD2000881은
# ------------------------------
# 39 pre: 두 화자는 이 대화에서
# ------------------------------
# 40 pre: 두 화자는 이 대화에서
# ------------------------------
# 41 pre: SD2000884와 SD2000885는
# ------------------------------
# 42 pre: SD2000884와 SD2000885는
# ------------------------------
# 43 pre: 두 화자는 이 대화에서
# ------------------------------
# 44 pre: 두 화자는 이 대화에서
# ------------------------------
# 45 pre: 이 대화에서 화자 SD2000886과 SD2000887은
# ------------------------------
# 46 pre: 이 대화에서 화자 SD2000887과 SD2000886은
# ------------------------------
# 47 pre: 이 대화에서 화자 SD2000894와 SD2000895는
# ------------------------------
# 48 pre: 이 대화에서 화자 SD2000894와 SD2000895는
# ------------------------------
# 49 pre: 두 화자는 이 대화에서
# ------------------------------
# 50 pre: 두 화자는 이 대화에서
# ------------------------------
# 51 pre: 이 대화에서 화자들은
# ------------------------------
# 52 pre: 이 대화에서 화자 SD2000902와 SD2000903은
# ------------------------------
# 53 pre: 두 화자는 이 대화에서
# ------------------------------
# 54 pre: 두 화자는 이 대화에서
# ------------------------------
# 55 pre: 이 대화에서 화자들은
# ------------------------------
# 56 pre: 이 대화에서 화자들은
# ------------------------------
# 57 pre: 두 화자는 이 대화에서
# ------------------------------
# 58 pre: 두 화자는 이 대화에서
# ------------------------------
# 59 pre: 이 대화에서 화자들은
# ------------------------------
# 60 pre: 이 대화에서 화자들은
# ------------------------------
# 61 pre: 두 화자는 이 대화에서
# ------------------------------
# 62 pre: 두 화자는 이 대화에서
# ------------------------------
# 63 pre: 이 대화에서 화자들은
# ------------------------------
# 64 pre: 이 대화에서 화자들은
# ------------------------------
# 65 pre: 두 화자는 이 대화에서
# ------------------------------
# 66 pre: 두 화자는 이 대화에서
# ------------------------------
# 67 pre: 이 대화에서 화자들은
# ------------------------------
# 68 pre: 이 대화에서 화자 SD2000926과 SD2000927은
# ------------------------------
# 69 pre: 두 화자는 이 대화에서
# ------------------------------
# 70 pre: 두 화자는 이 대화에서
# ------------------------------
# 71 pre: 이 대화에서 화자들은
# ------------------------------
# 72 pre: 이 대화에서 화자들은
# ------------------------------
# 73 pre: 두 화자는 이 대화에서
# ------------------------------
# 74 pre: 두 화자는 이 대화에서
# ------------------------------
# 75 pre: 이 대화에서 화자들은
# ------------------------------
# 76 pre: 이 대화에서 화자들은
# ------------------------------
# 77 pre: 두 화자는 이 대화에서
# ------------------------------
# 78 pre: 두 화자는 이 대화에서
# ------------------------------
# 79 pre: 이 대화에서 화자들은
# ------------------------------
# 80 pre: 이 대화에서 화자들은
# ------------------------------
# 81 pre: 두 화자는 이 대화에서
# ------------------------------
# 82 pre: 이 대화에서 화자들은
# ------------------------------
# 83 pre: 이 대화에서 화자들은
# ------------------------------
# 84 pre: 이 대화에서 화자들은
# ------------------------------
# 85 pre: 이 대화에서 화자들은
# ------------------------------
# 86 pre: 두 화자는 이 대화에서
# ------------------------------
# 87 pre: 두 화자는 이 대화에서
# ------------------------------
# 88 pre: 이 대화에서 화자 SD2001110과 화자 SD2001111은
# ------------------------------
# 89 pre: 이 대화에서 화자 SD2001110와 화자 SD2001111은
# ------------------------------
# 90 pre: 이 대화에서 화자 SD2000988과 화자 SD2000989는
# ------------------------------
# 91 pre: 이 대화에서 화자 SD2000988과 화자 SD2000989는
# ------------------------------
# 92 pre: 두 화자는 이 대화에서
# ------------------------------
# 93 pre: 두 화자는 이 대화에서
# ------------------------------
# 94 pre: 두 화자는 이 대화에서
# ------------------------------
# 95 pre: 두 화자는 이 대화에서
# ------------------------------
# 96 pre: 두 화자는 이 대화에서
# ------------------------------
# 97 pre: 두 화자는 이 대화에서
# ------------------------------
# 98 pre: 두 사람은
# ------------------------------
# 99 pre: 두 사람은
# ------------------------------
# 100 pre: 두 화자는 이 대화에서
# ------------------------------
# 101 pre: 두 화자는 이 대화에서
# ------------------------------
# 102 pre: 두 사람은
# ------------------------------
# 103 pre: 두 사람은
# ------------------------------
# 104 pre: 두 사람은
# ------------------------------
# 105 pre: 두 화자는 이 대화에서
# ------------------------------
# 106 pre: 두 화자는 이 대화에서
# ------------------------------
# 107 pre: 두 화자는 이 대화에서
# ------------------------------
# 108 pre: 두 화자는 이 대화에서
# ------------------------------
# 109 pre: 이 대화에서 화자 SD2001081과 SD2001083은
# ------------------------------
# 110 pre: 이 대화에서 화자 SD2001081과 SD2001083은
# ------------------------------
# 111 pre: 두 화자는 이 대화에서
# ------------------------------
# 112 pre: 두 화자는 이 대화에서
# ------------------------------
# 113 pre: 이 대화에서 화자 SD2001085와 SD2001086은
# ------------------------------
# 114 pre: 이 대화에서 화자 SD2001085와 SD2001086은
# ------------------------------
# 115 pre: 두 화자는 이 대화에서
# ------------------------------
# 116 pre: 두 화자는 이 대화에서
# ------------------------------
# 117 pre: 이 대화에서 화자 SD2001104와 SD2001105는
# ------------------------------
# 118 pre: 이 대화에서 화자 SD2001104와 SD2001105는
# ------------------------------
# 119 pre: 두 화자는 이 대화에서
# ------------------------------
# 120 pre: 두 화자는 이 대화에서
# ------------------------------
# 121 pre: 두 화자는 이 대화에서
# ------------------------------
# 122 pre: 두 화자는 이 대화에서
# ------------------------------
# 123 pre: 두 화자는 이 대화에서
# ------------------------------
# 124 pre: 두 화자는 이 대화에서
# ------------------------------
# 125 pre: 두 화자는 이 대화에서
# ------------------------------
# 126 pre: 두 화자는 이 대화에서
# ------------------------------
# 127 pre: 두 화자는 이 대화에서
# ------------------------------
# 128 pre: 두 화자는 이 대화에서
# ------------------------------
# 129 pre: 두 화자는 이 대화에서
# ------------------------------
# 130 pre: 두 화자는 이 대화에서
# ------------------------------
# 131 pre: 두 화자는 이 대화에서
# ------------------------------
# 132 pre: 두 화자는 이 대화에서
# ------------------------------
# 133 pre: 두 화자는 이 대화에서
# ------------------------------
# 134 pre: 두 화자는 이 대화에서
# ------------------------------
# 135 pre: 두 화자는 이 대화에서
# ------------------------------
# 136 pre: 두 화자는 이 대화에서
# ------------------------------
# 137 pre: 두 화자는 이 대화에서
# ------------------------------
# 138 pre: 두 화자는 이 대화에서
# ------------------------------
# 139 pre: 두 화자는 이 대화에서
# ------------------------------
# 140 pre: 두 화자는 이 대화에서
# ------------------------------
# 141 pre: 두 화자는 이 대화에서
# ------------------------------
# 142 pre: 두 화자는 이 대화에서
# ------------------------------
# 143 pre: 두 화자는 이 대화에서
# ------------------------------
# 144 pre: 두 화자는 이 대화에서
# ------------------------------
# 145 pre: 두 화자는 이 대화에서
# ------------------------------
# 146 pre: 두 화자는 이 대화에서
# ------------------------------
# 147 pre: 두 화자는 이 대화에서
# ------------------------------
# 148 pre: 두 화자는 이 대화에서
# ------------------------------
# 149 pre: 두 화자는 이 대화에서
# ------------------------------
# 150 pre: 두 화자는 이 대화에서
# ------------------------------
# 151 pre: 두 화자는 이 대화에서
# ------------------------------
# 152 pre: 두 화자는 이 대화에서
# ------------------------------
# 153 pre: 두 화자는 이 대화에서
# ------------------------------
# 154 pre: 두 화자는 이 대화에서
# ------------------------------
# 155 pre: 두 화자는 이 대화에서
# ------------------------------
# 156 pre: 두 화자는 이 대화에서
# ------------------------------
# 157 pre: 두 화자는 이 대화에서
# ------------------------------
# 158 pre: 두 화자는 이 대화에서
# ------------------------------
# 159 pre: 두 화자는 이 대화에서
# ------------------------------
# 160 pre: 두 화자는 이 대화에서
# ------------------------------
# 161 pre: 두 화자는 이 대화에서
# ------------------------------
# 162 pre: 두 화자는 이 대화에서
# ------------------------------
# 163 pre: 두 화자는 이 대화에서
# ------------------------------
# 164 pre: 두 화자는 이 대화에서
# ------------------------------
# 165 pre: 두 화자는 이 대화에서
# ------------------------------
# 166 pre: 두 화자는 이 대화에서
# ------------------------------
# 167 pre: 두 화자는 이 대화에서
# ------------------------------
# 168 pre: 두 화자는 이 대화에서
# ------------------------------
# 169 pre: 두 화자는 이 대화에서
# ------------------------------
# 170 pre: 두 화자는 이 대화에서
# ------------------------------
# 171 pre: 두 화자는 이 대화에서
# ------------------------------
# 172 pre: 두 화자는 이 대화에서
# ------------------------------
# 173 pre: 두 화자는 이 대화에서
# ------------------------------
# 174 pre: 두 화자는 이 대화에서
# ------------------------------
# 175 pre: 두 화자는 이 대화에서
# ------------------------------
# 176 pre: 두 화자는 이 대화에서
# ------------------------------
# 177 pre: 두 화자는 이 대화에서
# ------------------------------
# 178 pre: 두 화자는 이 대화에서
# ------------------------------
# 179 pre: 두 화자는 이 대화에서
# ------------------------------
# 180 pre: 두 화자는 이 대화에서
# ------------------------------
# 181 pre: 두 화자는 이 대화에서
# ------------------------------
# 182 pre: 두 화자는 이 대화에서
# ------------------------------
# 183 pre: 두 화자는 이 대화에서
# ------------------------------
# 184 pre: 두 화자는 이 대화에서
# ------------------------------
# 185 pre: 두 화자는 이 대화에서
# ------------------------------
# 186 pre: 두 화자는 이 대화에서
# ------------------------------
# 187 pre: 두 화자는 이 대화에서
# ------------------------------
# 188 pre: 두 화자는 이 대화에서
# ------------------------------
# 189 pre: 두 화자는 이 대화에서
# ------------------------------
# 190 pre: 두 화자는 이 대화에서
# ------------------------------
# 191 pre: 두 화자는 이 대화에서
# ------------------------------
# 192 pre: 두 화자는 이 대화에서
# ------------------------------
# 193 pre: 두 화자는 이 대화에서
# ------------------------------
# 194 pre: 두 화자는 이 대화에서
# ------------------------------
# 195 pre: 두 화자는 이 대화에서
# ------------------------------
# 196 pre: 두 화자는 이 대화에서
# ------------------------------
# 197 pre: 두 화자는 이 대화에서
# ------------------------------
# 198 pre: 이 대화에서 화자들은
# ------------------------------
# 199 pre: 이 대화에서 화자들은
# ------------------------------
# 200 pre: 이 대화에서 화자들은
# ------------------------------
# 201 pre: 이 대화에서 화자들은
# ------------------------------
# 202 pre: 이 대화에서 화자들은
# ------------------------------
# 203 pre: 이 대화에서 화자들은
# ------------------------------
# 204 pre: 이 대화에서 화자들은
# ------------------------------
# 205 pre: 이 대화에서 화자들은
# ------------------------------
# 206 pre: 이 대화에서 화자들은
# ------------------------------
# 207 pre: 이 대화에서 화자들은
# ------------------------------
# 208 pre: 이 대화에서 화자들은
# ------------------------------
# 209 pre: 이 대화에서 화자들은
# ------------------------------
# 210 pre: 이 대화에서 화자들은
# ------------------------------
# 211 pre: 이 대화에서 화자들은
# ------------------------------
# 212 pre: SD2001897과 SD2001898은
# ------------------------------
# 213 pre: SD2001897과 SD2001898은
# ------------------------------
# 214 pre: SD2002195와 SD2002196은
# ------------------------------
# 215 pre: SD2002195와 SD2002196은
# ------------------------------
# 216 pre: 이 대화에서 화자 SD2001925와 SD2001884는
# ------------------------------
# 217 pre: 이 대화에서 화자 SD2001884와 SD2001925는
# ------------------------------
# 218 pre: 이 대화에서 화자들은
# ------------------------------
# 219 pre: 이 대화에서 화자들은
# ------------------------------
# 220 pre: 이 대화에서 화자들은
# ------------------------------
# 221 pre: 이 대화에서 화자들은
# ------------------------------
# 222 pre: 이 대화에서 화자들은
# ------------------------------
# 223 pre: 이 대화에서 화자들은
# ------------------------------
# 224 pre: 두 화자는 이 대화에서
# ------------------------------
# 225 pre: 두 화자는 이 대화에서
# ------------------------------
# 226 pre: 이 대화에서 화자 SD2001966와 SD2001967은
# ------------------------------
# 227 pre: 이 대화에서 화자 SD2001966와 SD2001967은
# ------------------------------
# 228 pre: 이 대화에서 화자 SD2001968와 SD2001969는
# ------------------------------
# 229 pre: 이 대화에서 화자 SD2001968와 SD2001969는
# ------------------------------
# 230 pre: 두 화자는 이 대화에서
# ------------------------------
# 231 pre: 두 화자는 이 대화에서
# ------------------------------
# 232 pre: 두 사람은
# ------------------------------
# 233 pre: 두 사람은
# ------------------------------
# 234 pre: 두 사람은
# ------------------------------
# 235 pre: 두 사람은
# ------------------------------
# 236 pre: 두 사람은
# ------------------------------
# 237 pre: 두 사람은
# ------------------------------
# 238 pre: 두 사람은
# ------------------------------
# 239 pre: 두 사람은
# ------------------------------
# 240 pre: 이 대화에서 SD2002049와 SD2002050은
# ------------------------------
# 241 pre: 이 대화에서 SD2002049와 SD2002050은
# ------------------------------
# 242 pre: 이 대화에서 화자 SD2002059과 SD2002060은
# ------------------------------
# 243 pre: 이 대화에서 SD2002059와 SD2002060은
# ------------------------------
# 244 pre: 이 대화에서 SD2002331과 SD2002394는
# ------------------------------
# 245 pre: 이 대화에서 SD2002331과 SD2002394는
# ------------------------------
# 246 pre: 이 대화에서 SD2002075와 SD2002076은
# ------------------------------
# 247 pre: 이 대화에서 SD2002075와 SD2002076은
# ------------------------------
# 248 pre: 이 대화에서 화자들은
# ------------------------------
# 249 pre: 이 대화에서 화자들은
# ------------------------------
# 250 pre: 이 대화에서 화자들은
# ------------------------------
# 251 pre: 이 대화에서 화자들은
# ------------------------------
# 252 pre: 이 대화에서 화자들은
# ------------------------------
# 253 pre: 이 대화에서 화자들은
# ------------------------------
# 254 pre: 이 대화에서 화자 SD2002188과 SD2002191은
# ------------------------------
# 255 pre: 이 대화에서 화자 SD2002191과 SD2002188은
# ------------------------------
# 256 pre: 두 사람은
# ------------------------------
# 257 pre: 두 사람은
# ------------------------------
# 258 pre: 두 사람은
# ------------------------------
# 259 pre: 두 사람은
# ------------------------------
# 260 pre: SD2002282와 SD2002283은
# ------------------------------
# 261 pre: SD2002282와 SD2002283은
# ------------------------------
# 262 pre: 이 대화에서 화자 SD2002290과 SD2002291은
# ------------------------------
# 263 pre: 이 대화에서 화자 SD2002290과 SD2002291은
# ------------------------------
# 264 pre: 이 대화에서 화자 SD2002324와 SD2002325는
# ------------------------------
# 265 pre: 이 대화에서 화자들은
# ------------------------------
# 266 pre: 이 대화에서 화자들은
# ------------------------------
# 267 pre: 이 대화에서 화자들은
# ------------------------------
# 268 pre: 이 대화에서 화자들은
# ------------------------------
# 269 pre: 이 대화에서 화자들은
# ------------------------------
# 270 pre: 이 대화에서 두 화자는
# ------------------------------
# 271 pre: 두 화자는
# ------------------------------
# 272 pre: 이 대화에서 두 화자는
# ------------------------------
# 273 pre: 두 화자는
# ------------------------------
# 274 pre: 두 화자는
# ------------------------------
# 275 pre: 두 화자는
# ------------------------------
# 276 pre: 두 화자는
# ------------------------------
# 277 pre: 두 화자는
# ------------------------------
# 278 pre: 두 화자는
# ------------------------------
# 279 pre: 두 화자는
# ------------------------------
# 280 pre: 두 화자는
# ------------------------------
# 281 pre: 두 화자는
# ------------------------------
# 282 pre: 두 사람은
# ------------------------------
# 283 pre: 두 사람은
# ------------------------------
# 284 pre: 두 사람은
# ------------------------------
# 285 pre: 두 사람은
# ------------------------------
# 286 pre: 두 사람은
# ------------------------------
# 287 pre: 두 사람은
# ------------------------------
# 288 pre: 두 사람은
# ------------------------------
# 289 pre: 두 사람은
# ------------------------------
# 290 pre: 두 사람은
# ------------------------------
# 291 pre: 두 사람은
# ------------------------------
# 292 pre: 이 대화에서 SD2002605와 SD2002606은
# ------------------------------
# 293 pre: 이 대화에서 SD2002605와 SD2002606은
# ------------------------------
# 294 pre: 이 대화에서 SD2100003과 SD2100004는
# ------------------------------
# 295 pre: 이 대화에서 SD2100003과 SD2100004는
# ------------------------------
# 296 pre: 이 대화에서 SD2100005와 SD2100006은
# ------------------------------
# 297 pre: 이 대화에서 SD2100005와 SD2100006은
# ------------------------------
# 298 pre: 이 대화에서 화자들은
# ------------------------------
# 299 pre: 이 대화에서 화자들은
# ------------------------------
# 300 pre: 이 대화에서 화자들은
# ------------------------------
# 301 pre: 이 대화에서 화자들은
# ------------------------------
# 302 pre: 이 대화에서 화자들은
# ------------------------------
# 303 pre: 이 대화에서 화자들은
# ------------------------------
# 304 pre: 이 대화에서 화자들은
# ------------------------------
# 305 pre: 이 대화에서 화자들은
# ------------------------------
# 306 pre: 이 대화에서 화자들은
# ------------------------------
# 307 pre: 이 대화에서 화자들은
# ------------------------------
# 308 pre: 이 대화에서 화자들은
# ------------------------------
# 309 pre: 이 대화에서 화자들은
# ------------------------------
# 310 pre: 이 대화에서 화자들은
# ------------------------------
# 311 pre: 이 대화에서 화자들은
# ------------------------------
# 312 pre: 이 대화에서 화자들은
# ------------------------------
# 313 pre: 이 대화에서 화자들은
# ------------------------------
# 314 pre: 이 대화에서 화자들은
# ------------------------------
# 315 pre: 이 대화에서 화자들은
# ------------------------------
# 316 pre: 이 대화에서 화자들은
# ------------------------------
# 317 pre: 이 대화에서 화자들은
# ------------------------------
# 318 pre: 이 대화에서 화자들은
# ------------------------------
# 319 pre: 이 대화에서 화자들은
# ------------------------------
# 320 pre: 이 대화에서 화자들은
# ------------------------------
# 321 pre: 이 대화에서 화자들은
# ------------------------------
# 322 pre: 이 대화에서 화자들은
# ------------------------------
# 323 pre: 이 대화에서 화자들은
# ------------------------------
# 324 pre: 이 대화에서 화자들은
# ------------------------------
# 325 pre: 이 대화에서 화자들은
# ------------------------------
# 326 pre: 화자들은
# ------------------------------
# 327 pre: 화자들은
# ------------------------------
# 328 pre: 이 대화에서 화자들은
# ------------------------------
# 329 pre: 두 사람은
# ------------------------------
# 330 pre: 두 사람은
# ------------------------------
# 331 pre: 두 화자는
# ------------------------------
# 332 pre: 두 화자는
# ------------------------------
# 333 pre: 화자들은
# ------------------------------
# 334 pre: 화자들은
# ------------------------------
# 335 pre: 화자들은
# ------------------------------
# 336 pre: 화자들은
# ------------------------------
# 337 pre: 화자들은
# ------------------------------
# 338 pre: 화자들은
# ------------------------------
# 339 pre: 두 사람은
# ------------------------------
# 340 pre: 두 사람은
# ------------------------------
# 341 pre: 두 사람은
# ------------------------------
# 342 pre: 두 사람은
# ------------------------------
# 343 pre: 두 사람은
# ------------------------------
# 344 pre: 두 사람은
# ------------------------------
# 345 pre: 두 사람은
# ------------------------------
# 346 pre: 두 사람은
# ------------------------------
# 347 pre: 두 사람은
# ------------------------------
# 348 pre: 두 사람은
# ------------------------------
# 349 pre: 이 대화에서 화자들은
# ------------------------------
# 350 pre: 화자들은
# ------------------------------
# 351 pre: 화자들은
# ------------------------------
# 352 pre: 화자들은
# ------------------------------
# 353 pre: 화자들은
# ------------------------------
# 354 pre: 이 대화에서 화자들은
# ------------------------------
# 355 pre: 화자들은
# ------------------------------
# 356 pre: 이 대화에서 화자들은
# ------------------------------
# 357 pre: 이 대화에서 화자들은
# ------------------------------
# 358 pre: 이 대화에서 화자들은
# ------------------------------
# 359 pre: 화자들은
# ------------------------------
# 360 pre: 화자들은
# ------------------------------
# 361 pre: 화자들은
# ------------------------------
# 362 pre: 화자들은
# ------------------------------
# 363 pre: 화자들은
# ------------------------------
# 364 pre: 두 사람은
# ------------------------------
# 365 pre: 두 사람은
# ------------------------------
# 366 pre: 두 사람은
# ------------------------------
# 367 pre: 두 사람은
# ------------------------------
# 368 pre: 두 사람은
# ------------------------------
# 369 pre: 두 사람은
# ------------------------------
# 370 pre: 화자들은
# ------------------------------
# 371 pre: 화자들은
# ------------------------------
# 372 pre: 화자들은
# ------------------------------
# 373 pre: 화자들은
# ------------------------------
# 374 pre: 두 사람은
# ------------------------------
# 375 pre: 두 사람은
# ------------------------------
# 376 pre: 두 사람은
# ------------------------------
# 377 pre: 두 사람은
# ------------------------------
# 378 pre: 두 사람은
# ------------------------------
# 379 pre: 두 사람은
# ------------------------------
# 380 pre: 두 사람은
# ------------------------------
# 381 pre: 두 사람은
# ------------------------------
# 382 pre: 두 사람은
# ------------------------------
# 383 pre: 두 사람은
# ------------------------------
# 384 pre: 두 사람은
# ------------------------------
# 385 pre: 두 사람은
# ------------------------------
# 386 pre: 두 사람은
# ------------------------------
# 387 pre: 두 사람은
# ------------------------------
# 388 pre: 두 사람은
# ------------------------------
# 389 pre: 두 사람은
# ------------------------------
# 390 pre: 두 사람은
# ------------------------------
# 391 pre: 두 사람은
# ------------------------------
# 392 pre: 두 사람은
# ------------------------------
# 393 pre: 두 사람은
# ------------------------------
# 394 pre: 두 사람은
# ------------------------------
# 395 pre: 두 사람은
# ------------------------------
# 396 pre: SD2110499와 SD2110500은
# ------------------------------
# 397 pre: 대화에서 SD2110499와 SD2110500은
# ------------------------------
# 398 pre: SD2100501과 SD2100502는
# ------------------------------
# 399 pre: SD2100501과 SD2100502는
# ------------------------------
# 400 pre: 대화에서 SD2100503과 SD2110504는
# ------------------------------
# 401 pre: 이 대화에서 SD2100503과 SD2110504는
# ------------------------------
# 402 pre: 이 대화에서 화자들은
# ------------------------------
# 403 pre: 이 대화에서 화자들은
# ------------------------------
# 404 pre: 이 대화에서 화자들은
# ------------------------------
# 405 pre: 이 대화에서는
# ------------------------------
# 406 pre: 이 대화에서 화자 SD2100515와 SD2100516은
# ------------------------------
# 407 pre: 이 대화에서 화자 SD2100515와 SD2100516은
# ------------------------------
# 408 pre: 이 대화에서 화자 SD2100516과 SD2100515는
# ------------------------------
# 409 pre: 이 대화에서 화자 SD2100516과 SD2100515는
# ------------------------------
# 410 pre: 이 대화에서 화자 SD2100517과 SD2100518은
# ------------------------------
# 411 pre: 이 대화에서 화자 SD2100518과 SD2100517은
# ------------------------------
# 412 pre: 이 대화에서 화자 SD2100517과 SD2100518은
# ------------------------------
# 413 pre: 이 대화에서 화자 SD2100517과 SD2100518은
# ------------------------------
# 414 pre: 이 대화에서 화자 SD2100524와 SD2110523은
# ------------------------------
# 415 pre: 이 대화에서 화자 SD2100524와 SD2110523은
# ------------------------------
# 416 pre: 이 대화에서 화자 SD2100525와 SD2100526은
# ------------------------------
# 417 pre: 두 화자는 이 대화에서
# ------------------------------
# 418 pre: 이 대화에서 화자들은
# ------------------------------
# 419 pre: 이 대화에서 화자들은
# ------------------------------
# 420 pre: 이 대화에서 화자들은
# ------------------------------
# 421 pre: 이 대화에서 화자들은
# ------------------------------
# 422 pre: 이 대화에서 화자들은
# ------------------------------
# 423 pre: 이 대화에서 화자들은
# ------------------------------
# 424 pre: 이 대화에서 화자들은
# ------------------------------
# 425 pre: 이 대화에서 화자들은
# ------------------------------
# 426 pre: 이 대화에서 화자들은
# ------------------------------
# 427 pre: 이 대화에서 화자들은
# ------------------------------
# 428 pre: 이 대화에서 화자들은
# ------------------------------
# 429 pre: 이 대화에서 화자들은
# ------------------------------
# 430 pre: 이 대화에서 화자들은
# ------------------------------
# 431 pre: 이 대화에서 화자들은
# ------------------------------
# 432 pre: 이 대화에서 화자들은
# ------------------------------
# 433 pre: 이 대화에서 화자들은
# ------------------------------
# 434 pre: 이 대화에서 화자들은
# ------------------------------
# 435 pre: 이 대화에서 화자들은
# ------------------------------
# 436 pre: 두 화자는 이 대화에서
# ------------------------------
# 437 pre: 이 대화에서 두 화자는
# ------------------------------
# 438 pre: 이 대화에서 두 화자들은
# ------------------------------
# 439 pre: 두 화자는 이 대화에서
# ------------------------------
# 440 pre: 두 화자는 이 대화에서
# ------------------------------
# 441 pre: 두 화자는 이 대화에서
# ------------------------------
# 442 pre: 두 화자는 이 대화에서
# ------------------------------
# 443 pre: 두 화자는 이 대화에서
# ------------------------------
# 444 pre: 이 대화에서 두 화자는
# ------------------------------
# 445 pre: 두 화자는
# ------------------------------
# 446 pre: 이 대화에서 화자들은
# ------------------------------
# 447 pre: 이 대화에서 화자들은
# ------------------------------
# 448 pre: 이 대화에서 화자들은
# ------------------------------
# 449 pre: 이 대화에서 화자들은
# ------------------------------
# 450 pre: 두 화자는
# ------------------------------
# 451 pre: 두 화자는
# ------------------------------
# 452 pre: 두 화자는
# ------------------------------
# 453 pre: 두 화자는 이 대화에서
# ------------------------------
# 454 pre: 두 사람은
# ------------------------------
# 455 pre: 두 사람은
# ------------------------------
# 456 pre: 두 사람은
# ------------------------------
# 457 pre: 두 사람은
# ------------------------------
# 458 pre: 두 사람은
# ------------------------------
# 459 pre: 두 사람은
# ------------------------------
# 460 pre: 두 사람은
# ------------------------------
# 461 pre: 두 사람은
# ------------------------------
# 462 pre: 두 사람은
# ------------------------------
# 463 pre: 두 사람은
# ------------------------------
# 464 pre: 두 사람은
# ------------------------------
# 465 pre: 두 사람은
# ------------------------------
# 466 pre: 두 사람은
# ------------------------------
# 467 pre: 두 사람은
# ------------------------------
# 468 pre: 두 사람은
# ------------------------------
# 469 pre: 두 사람은
# ------------------------------
# 470 pre: 두 사람은
# ------------------------------
# 471 pre: 두 사람은
# ------------------------------
# 472 pre: 두 사람은
# ------------------------------
# 473 pre: 두 사람은
# ------------------------------
# 474 pre: 두 화자는
# ------------------------------
# 475 pre: 두 화자는
# ------------------------------
# 476 pre: 이 대화에서 두 화자는
# ------------------------------
# 477 pre: 이 대화에서 두 화자는
# ------------------------------
# 478 pre: 두 화자는
# ------------------------------
# 479 pre: 두 화자는 이 대화에서
# ------------------------------
# 480 pre: 이 대화에서 화자들은
# ------------------------------
# 481 pre: 이 대화에서 화자들은
# ------------------------------
# 482 pre: 두 화자는 이 대화에서
# ------------------------------
# 483 pre: 두 화자는 이 대화에서
# ------------------------------
# 484 pre: 이 대화에서 두 화자는
# ------------------------------
# 485 pre: 이 대화에서 화자들은
# ------------------------------
# 486 pre: 이 대화에서 화자들은
# ------------------------------
# 487 pre: 이 대화에서 화자들은
# ------------------------------
# 488 pre: 이 대화에서 SD2100583과 SD2100584는
# ------------------------------
# 489 pre: 이 대화에서 SD2100583과 SD2100584는
# ------------------------------
# 490 pre: 이 대화에서 SD2100585와 SD2100586은
# ------------------------------
# 491 pre: 이 대화에서 SD2100585와 SD2100586은
# ------------------------------
# 492 pre: 이 대화에서 SD2100585와 SD2100586은
# ------------------------------
# 493 pre: 이 대화에서 SD2100585와 SD2100586은
# ------------------------------
# 494 pre: 두 화자는
# ------------------------------
# 495 pre: 이 대화에서 화자들은
# ------------------------------
# 496 pre: 이 대화에서 화자들은
# ------------------------------
# 497 pre: 이 대화에서 화자들은
# ------------------------------
# 498 pre: 두 화자는 이 대화에서
# ------------------------------
# 499 pre: 두 화자는 이 대화에서
# ------------------------------
# 500 pre: 두 화자는 이 대화에서
# ------------------------------
# 501 pre: 두 화자는 이 대화에서
# ------------------------------
# 502 pre: 이 대화에서 화자들은
# ------------------------------
# 503 pre: 이 대화에서 화자들은
# ------------------------------
# 504 pre: 이 대화에서 화자들은
# ------------------------------
# 505 pre: 이 대화에서 화자들은
# ------------------------------

# %%
find_before_type(dev_df)
# Out:
# 0 pre: 두 화자는 이 대화에서
# ------------------------------
# 1 pre: 두 화자는 이 대화에서
# ------------------------------
# 2 pre: 두 화자는 이 대화에서
# ------------------------------
# 3 pre: 두 사람은
# ------------------------------
# 4 pre: 두 사람은
# ------------------------------
# 5 pre: 두 화자는 이 대화에서
# ------------------------------
# 6 pre: 두 화자는 이 대화에서
# ------------------------------
# 7 pre: 두 화자는 이 대화에서
# ------------------------------
# 8 pre: 두 화자는 이 대화에서
# ------------------------------
# 9 pre: 두 사람은
# ------------------------------
# 10 pre: 두 사람은
# ------------------------------
# 11 pre: 두 화자는 이 대화에서
# ------------------------------
# 12 pre: 두 화자는 이 대화에서
# ------------------------------
# 13 pre: 이 대화에서 두 화자는
# ------------------------------
# 14 pre: 이 대화에서 두 화자는
# ------------------------------
# 15 pre: 이 대화에서 두 화자는
# ------------------------------
# 16 pre: 이 대화에서 두 화자는
# ------------------------------
# 17 pre: 두 화자는 이 대화에서
# ------------------------------
# 18 pre: 두 화자는 이 대화에서
# ------------------------------
# 19 pre: 두 화자는 이 대화에서
# ------------------------------
# 20 pre: 두 화자는 이 대화에서
# ------------------------------
# 21 pre: 이 대화에서 두 화자는
# ------------------------------
# 22 pre: 이 대화에서 두 화자는
# ------------------------------
# 23 pre: 이 대화에서 두 화자는
# ------------------------------
# 24 pre: 이 대화에서 두 화자는
# ------------------------------
# 25 pre: 두 화자는 이 대화에서
# ------------------------------
# 26 pre: 두 화자는 이 대화에서
# ------------------------------
# 27 pre: 이 대화에서 화자들은
# ------------------------------
# 28 pre: 이 대화에서 화자들은
# ------------------------------
# 29 pre: 두 화자는 이 대화에서
# ------------------------------
# 30 pre: 두 화자는 이 대화에서
# ------------------------------
# 31 pre: 이 대화에서 화자들은
# ------------------------------
# 32 pre: 이 대화에서 화자들은
# ------------------------------
# 33 pre: 두 화자는 이 대화에서
# ------------------------------
# 34 pre: 두 화자는 이 대화에서
# ------------------------------
# 35 pre: 두 화자는 이 대화에서
# ------------------------------
# 36 pre: 두 화자는 이 대화에서
# ------------------------------
# 37 pre: 이 대화에서 화자들은
# ------------------------------
# 38 pre: 이 대화에서 화자들은
# ------------------------------
# 39 pre: 이 대화에서 화자들은
# ------------------------------
# 40 pre: 이 대화에서 화자들은
# ------------------------------
# 41 pre: 이 대화에서 화자들은
# ------------------------------
# 42 pre: 이 대화에서 화자들은
# ------------------------------
# 43 pre: 두 화자는 이 대화에서
# ------------------------------
# 44 pre: 두 화자는 이 대화에서
# ------------------------------
# 45 pre: 이 대화에서 화자들은
# ------------------------------
# 46 pre: 이 대화에서 화자들은
# ------------------------------
# 47 pre: 두 화자는 이 대화에서
# ------------------------------
# 48 pre: 두 화자는 이 대화에서
# ------------------------------
# 49 pre: 이 대화에서 화자들은
# ------------------------------
# 50 pre: 이 대화에서 화자들은
# ------------------------------
# 51 pre: 두 화자는 이 대화에서
# ------------------------------
# 52 pre: 두 화자는 이 대화에서
# ------------------------------
# 53 pre: 이 대화에서 화자들은
# ------------------------------
# 54 pre: 이 대화에서 화자들은
# ------------------------------
# 55 pre: 두 화자는 이 대화에서
# ------------------------------
# 56 pre: 두 화자는 이 대화에서
# ------------------------------
# 57 pre: 두 화자는 이 대화에서
# ------------------------------
# 58 pre: 두 화자는 이 대화에서
# ------------------------------
# 59 pre: 두 화자는 이 대화에서
# ------------------------------
# 60 pre: 두 화자는 이 대화에서
# ------------------------------
# 61 pre: 이 대화에서 화자들은
# ------------------------------
# 62 pre: 이 대화에서 화자들은
# ------------------------------
# 63 pre: 두 화자는 이 대화에서
# ------------------------------
# 64 pre: 두 화자는 이 대화에서
# ------------------------------
# 65 pre: 이 대화에서 화자들은
# ------------------------------
# 66 pre: 이 대화에서 화자들은
# ------------------------------
# 67 pre: 두 화자는 이 대화에서
# ------------------------------
# 68 pre: 두 화자는 이 대화에서
# ------------------------------
# 69 pre: 이 대화에서 화자들은
# ------------------------------
# 70 pre: 이 대화에서 화자들은
# ------------------------------
# 71 pre: 두 화자는 이 대화에서
# ------------------------------
# 72 pre: 두 화자는 이 대화에서
# ------------------------------
# 73 pre: 두 화자는 이 대화에서
# ------------------------------
# 74 pre: 이 대화에서 화자들은
# ------------------------------
# 75 pre: 이 대화에서 화자들은
# ------------------------------
# 76 pre: 이 대화에서 화자들은
# ------------------------------
# 77 pre: 두 화자는 이 대화에서
# ------------------------------
# 78 pre: 두 화자는 이 대화에서
# ------------------------------
# 79 pre: 이 대화에서 화자들은
# ------------------------------
# 80 pre: 이 대화에서 화자들은
# ------------------------------
# 81 pre: 두 화자는 이 대화에서
# ------------------------------
# 82 pre: 두 화자는 이 대화에서
# ------------------------------
# 83 pre: 이 대화에서 화자들은
# ------------------------------
# 84 pre: 이 대화에서 화자들은
# ------------------------------
# 85 pre: 두 화자는 이 대화에서
# ------------------------------
# 86 pre: 두 화자는 이 대화에서
# ------------------------------
# 87 pre: 이 대화에서 화자들은
# ------------------------------
# 88 pre: 이 대화에서 화자들은
# ------------------------------
# 89 pre: 두 화자는 이 대화에서
# ------------------------------
# 90 pre: 두 화자는 이 대화에서
# ------------------------------
# 91 pre: SD2000862와 SD2000863은
# ------------------------------
# 92 pre: 두 화자는 이 대화에서
# ------------------------------
# 93 pre: 두 화자는 이 대화에서
# ------------------------------
# 94 pre: 두 화자는 이 대화에서
# ------------------------------
# 95 pre: SD2000865와 SD2000866은
# ------------------------------
# 96 pre: SD2000865와 SD2000866은
# ------------------------------
# 97 pre: 두 화자는 이 대화에서
# ------------------------------
# 98 pre: 두 화자는 이 대화에서
# ------------------------------
# 99 pre: SD2000867과 SD2000868은
# ------------------------------
# 100 pre: SD2000867과 SD2000868은
# ------------------------------
# 101 pre: 두 화자는 이 대화에서
# ------------------------------

# %% [markdown]
# ### 확인 결과
#
# - type 앞에 특별하게 요약과 관련된 내용 존재 x
# - 즉, 현재 type을 적절하게 잘 뽑아낸 것이라 볼 수 있음
# - 모델이 이 여러가지 타입을 맞추는 것이 아닌
# - 핵심에 해당하는 "전반적인 요약"에 집중할 수 있게끔
# - type을 가장 보편적인 `두 화자는 이 대화에서` 하나로 통일

# %% [markdown]
# ### 통일 이후

# %%
train_df = make_dataframe('./train.json')
dev_df = make_dataframe('./dev.json')
test_df = make_dataframe('./test.json')

# %%
find_common_ngrams(train_df, 4)
# Out:
# {('두', '화자는', '이', '대화에서'): 506,
#  ('화자는', '이', '대화에서', '좋아하는'): 23,
#  ('화자는', '이', '대화에서', '기억에'): 13,
#  ('이', '대화에서', '기억에', '남는'): 13,
#  ('화자는', '이', '대화에서', '건강'): 12,
#  ('화자는', '이', '대화에서', '여행'): 9,
#  ('화자는', '이', '대화에서', '선호하는'): 9,
#  ('화자는', '이', '대화에서', '자신의'): 7,
#  ('화자는', '이', '대화에서', '가족'): 7,
#  ('화자는', '이', '대화에서', '영화'): 5,
#  ('화자는', '이', '대화에서', '운동에'): 5,
#  ('이', '대화에서', '가고', '싶은'): 5,
#  ('화자는', '이', '대화에서', '아르바이트'): 5,
#  ('화자는', '이', '대화에서', '다이어트'): 5,
#  ('화자는', '이', '대화에서', '가고'): 5,
#  ('화자는', '이', '대화에서', '운동과'): 5,
#  ('화자는', '이', '대화에서', '요즘'): 5,
#  ('화자는', '이', '대화에서', '자녀의'): 4,
#  ('화자는', '이', '대화에서', '결혼과'): 4,
#  ('이', '대화에서', '건강', '관리에'): 4,
#  ('화자는', '이', '대화에서', '최근'): 4,
#  ('이', '대화에서', '운동에', '대해'): 4,
#  ('화자는', '이', '대화에서', '가족에'): 4,
#  ('화자는', '이', '대화에서', '키우고'): 4,
#  ('화자는', '이', '대화에서', '건강을'): 4,
#  ('화자는', '이', '대화에서', '자주'): 4,
#  ('화자는', '이', '대화에서', '결혼에'): 4,
#  ('화자는', '이', '대화에서', '대화에서'): 4,
#  ('화자는', '이', '대화에서', '선물에'): 4,
#  ('이', '대화에서', '인상', '깊었던'): 3,
#  ('화자는', '이', '대화에서', '여행에'): 3,
#  ('이', '대화에서', '가족에', '대해'): 3,
#  ('이', '대화에서', '결혼에', '대해'): 3,
#  ('대화에서', '자신의', '성격에', '대해'): 3,
#  ('화자는', '이', '대화에서', '성격의'): 3,
#  ('음식에', '관한', '대화를', '나눴습니다'): 3,
#  ('이', '대화에서', '맛집에', '대해'): 3,
#  ('대화에서', '운동에', '대해', '이야기했습니다'): 3,
#  ('싶은', '선물에', '대해', '말했습니다'): 3,
#  ('화자는', '이', '대화에서', '맛집에'): 3,
#  ('받고', '싶은', '선물에', '대해'): 3,
#  ('대화에서', '가족에', '대해', '이야기했습니다'): 3,
#  ('화자는', '이', '대화에서', '인상'): 3,
#  ('이', '대화에서', '선물에', '대한'): 3,
#  ('이', '대화에서', '자신의', '성격에'): 3,
#  ('화자는', '이', '대화에서', '결혼식에'): 3,
#  ('화자는', '이', '대화에서', '현재'): 3,
#  ('화자는', '이', '대화에서', '여행,'): 3,
#  ('이', '대화에서', '혈액형', '별'): 3,
#  ('대화에서', '맛집에', '대해', '이야기했습니다'): 3,
#  ('화자는', '이', '대화에서', '티브이'): 3,
#  ('대화에서', '건강', '관리에', '대해'): 3,
#  ('이', '대화에서', '자주', '보는'): 3,
#  ('화자는', '이', '대화에서', '음악'): 3,
#  ('화자는', '이', '대화에서', '혈액형'): 3,
#  ('화자는', '이', '대화에서', '다이어트에'): 3,
#  ('화자는', '이', '대화에서', '취업'): 3,
#  ('가고', '싶은', '여행지에', '대해'): 3,
#  ('화자는', '이', '대화에서', '학창'): 3,
#  ('대화에서', '가고', '싶은', '여행지와'): 3,
#  ('화자는', '이', '대화에서', '받고'): 3,
#  ('이', '대화에서', '좋아하는', '음식과'): 3,
#  ('화자는', '이', '대화에서', '좋았던'): 2,
#  ('대화에서', '진로', '관련', '고민에'): 2,
#  ('화자는', '이', '대화에서', '스포츠'): 2,
#  ('화자는', '이', '대화에서', '다이어트와'): 2,
#  ('아르바이트와', '하고', '싶은', '아르바이트에'): 2,
#  ('이', '대화에서', '계절과', '날씨에'): 2,
#  ('화자는', '이', '대화에서', '추천하는'): 2,
#  ('스타일에', '대해', '이야기를', '나눴습니다'): 2,
#  ('화자는', '이', '대화에서', '형제'): 2,
#  ('이', '대화에서', '선호하는', '음식에'): 2,
#  ('대화에서', '음식에', '대해', '이야기했습니다'): 2,
#  ('화자는', '이', '대화에서', '영화를'): 2,
#  ('국내', '여행지에', '대해', '이야기했습니다'): 2,
#  ('이', '대화에서', '자녀의', '꿈에'): 2,
#  ('이', '대화에서', '여행', '가서'): 2,
#  ('대화에서', '다이어트에', '대해', '이야기했습니다'): 2,
#  ('화자는', '이', '대화에서', '음식에'): 2,
#  ('방법에', '대해', '이야기를', '나눴습니다'): 2,
#  ('화자는', '이', '대화에서', '건강과'): 2,
#  ('선호하는', '음식에', '대해', '이야기했습니다'): 2,
#  ('경험에', '대한', '이야기를', '나눴습니다'): 2,
#  ('이', '대화에서', '여행에', '관한'): 2,
#  ('싶은', '여행지에', '대해', '이야기했습니다'): 2,
#  ('이', '대화에서', '좋아하는', '계절에'): 2,
#  ('대화에서', '여행에', '관한', '대화를'): 2,
#  ('이', '대화에서', '건강에', '대해'): 2,
#  ('이', '대화에서', '영화에', '대해'): 2,
#  ('화자는', '이', '대화에서', '제주도와'): 2,
#  ('화자는', '이', '대화에서', '하고'): 2,
#  ('듣는', '음악에', '대해', '이야기했습니다'): 2,
#  ('쇼핑하는', '방법에', '대해', '이야기했습니다'): 2,
#  ('장르에', '대해', '이야기를', '나눴습니다'): 2,
#  ('프로그램에', '관한', '대화를', '나눴습니다'): 2,
#  ('화자는', '이', '대화에서', '추천하고'): 2,
#  ('이', '대화에서', '영화', '관람'): 2,
#  ('화자는', '이', '대화에서', '반려동물'): 2,
#  ('선물에', '관한', '대화를', '나눴습니다'): 2,
#  ('관계에', '대해', '대화를', '나눴습니다'): 2,
#  ('이', '대화에서', '가족과', '함께'): 2,
#  ('화자는', '이', '대화에서', '배우자를'): 2,
#  ('대화에서', '자녀의', '꿈에', '대해'): 2,
#  ('대화에서', '기억에', '남는', '여행지에'): 2,
#  ('화자는', '이', '대화에서', '본인의'): 2,
#  ('관련', '고민에', '대해', '이야기했습니다'): 2,
#  ('기억에', '남는', '여행지에', '대해'): 2,
#  ('화자는', '이', '대화에서', '가족의'): 2,
#  ('여행지에', '관한', '대화를', '나눴습니다'): 2,
#  ('화자는', '이', '대화에서', '먹고'): 2,
#  ('이', '대화에서', '요즘', '듣는'): 2,
#  ('자신', '있는', '요리에', '대해'): 2,
#  ('화자는', '이', '대화에서', '가족들에게'): 2,
#  ('화자는', '이', '대화에서', '투자에'): 2,
#  ('이', '대화에서', '티브이', '프로그램에'): 2,
#  ('이', '대화에서', '좋아하는', '계절과'): 2,
#  ('대화에서', '쇼핑하는', '방법에', '대해'): 2,
#  ('대화에서', '티브이', '프로그램에', '대해'): 2,
#  ('화자는', '이', '대화에서', '맛집'): 2,
#  ('화자는', '이', '대화에서', '건강에'): 2,
#  ('음식에', '관한', '대화를', '했습니다'): 2,
#  ('화자는', '이', '대화에서', '엠비티아이,'): 2,
#  ('티브이', '프로그램에', '대해', '이야기했습니다'): 2,
#  ('이', '대화에서', '아르바이트', '경험에'): 2,
#  ('대화에서', '선호하는', '음식에', '대해'): 2,
#  ('이', '대화에서', '다이어트', '방법과'): 2,
#  ('기억에', '남는', '일화에', '대해'): 2,
#  ('대화에서', '좋아하는', '영화', '장르와'): 2,
#  ('이', '대화에서', '결혼식에', '대해'): 2,
#  ('중', '기억에', '남는', '일화에'): 2,
#  ('남는', '선물과', '받고', '싶은'): 2,
#  ('싶은', '여행지에', '대해', '말했습니다'): 2,
#  ('있는', '요리에', '대해', '말했습니다'): 2,
#  ('대화에서', '좋아하는', '계절에', '대해'): 2,
#  ('수상', '레저에', '대해', '이야기했습니다'): 2,
#  ('대화에서', '영화에', '대해', '이야기했습니다'): 2,
#  ('화자는', '이', '대화에서', '오늘'): 2,
#  ('화자는', '이', '대화에서', '코로나'): 2,
#  ('기억에', '남는', '선물과', '받고'): 2,
#  ('화자는', '이', '대화에서', '사고'): 2,
#  ('이', '대화에서', '다이어트에', '대해'): 2,
#  ('여행', '스타일에', '대해', '이야기했습니다'): 2,
#  ('화자는', '이', '대화에서', '가족과'): 2,
#  ('이', '대화에서', '투자에', '대해'): 2,
#  ('경험에', '대해', '대화를', '나눴습니다'): 2,
#  ('화자는', '이', '대화에서', '먹거리에'): 2,
#  ('선호하는', '여행', '스타일에', '대해'): 2,
#  ('방송', '프로그램에', '관한', '대화를'): 2,
#  ('이', '대화에서', '건강을', '위한'): 2,
#  ('화자는', '이', '대화에서', '고등학교'): 2,
#  ('여행지에서의', '음식에', '관한', '대화를'): 2,
#  ('대화에서', '투자에', '대해', '대화했습니다'): 2,
#  ('꿈과', '목표에', '대해', '이야기했습니다'): 2,
#  ('이', '대화에서', '먹고', '싶은'): 2,
#  ('이', '대화에서', '사고', '싶은'): 2,
#  ('대화에서', '기억에', '남는', '선물과'): 2,
#  ('이', '대화에서', '먹거리에', '대해'): 2,
#  ('대화에서', '영화', '관람', '스타일에'): 2,
#  ('이', '대화에서', '쇼핑하는', '방법에'): 2,
#  ('화자는', '이', '대화에서', '풋살'): 2,
#  ('화자는', '이', '대화에서', '선물을'): 2,
#  ('화자는', '이', '대화에서', '쇼핑하는'): 2,
#  ('자신의', '성격에', '대해', '이야기했습니다'): 2,
#  ('가보고', '싶은', '여행지에', '대해'): 2,
#  ('여행지에', '대해', '대화를', '나눴습니다'): 2,
#  ('화자는', '이', '대화에서', '연예인의'): 2,
#  ('이', '대화에서', '음식에', '대해'): 2,
#  ('화자는', '이', '대화에서', '자녀'): 2,
#  ('화자는', '이', '대화에서', '유럽'): 2,
#  ('음식과', '요리에', '대해', '이야기했습니다'): 2,
#  ('여행에', '관한', '대화를', '했습니다'): 2,
#  ('이', '대화에서', '좋아하는', '영화'): 2,
#  ('진로', '관련', '고민에', '대해'): 2,
#  ('화자는', '이', '대화에서', '영화에'): 2,
#  ('건강', '관리에', '대해', '말했습니다'): 2,
#  ('화자는', '이', '대화에서', '계절과'): 2,
#  ('이', '대화에서', '취직에', '대해'): 2,
#  ('화자는', '이', '대화에서', '결혼'): 2,
#  ('이', '대화에서', '진로', '관련'): 2,
#  ('화자는', '이', '대화에서', '엠비티아이'): 2,
#  ('영화', '관람', '스타일에', '대해'): 2,
#  ('이', '대화에서', '여행', '계획,'): 2,
#  ('이', '대화에서', '받고', '싶은'): 2,
#  ('화자는', '이', '대화에서', '진로'): 2,
#  ('자녀의', '꿈에', '대해', '말했습니다'): 2,
#  ('이', '대화에서', '추천하고', '싶은'): 2,
#  ('이', '대화에서', '아르바이트', '경험과'): 2,
#  ('화자는', '이', '대화에서', '제사에'): 2,
#  ('꿈과', '목표에', '대해', '말했습니다'): 2,
#  ('화자는', '이', '대화에서', '취직에'): 2,
#  ('대화에서', '아르바이트', '경험에', '대해'): 2,
#  ('이', '대화에서', '키우고', '싶은'): 2,
#  ('대화에서', '먹고', '싶은', '음식과'): 2,
#  ('화자는', '이', '대화에서', '여행지에서'): 2,
#  ('선물과', '받고', '싶은', '선물에'): 2,
#  ('가고', '싶은', '여행지와', '여행'): 2}

# %%
find_common_ngrams(dev_df, 4)
# Out:
# {('두', '화자는', '이', '대화에서'): 102,
#  ('화자는', '이', '대화에서', '좋아하는'): 12,
#  ('화자는', '이', '대화에서', '건강'): 5,
#  ('화자는', '이', '대화에서', '이'): 4,
#  ('이', '대화에서', '이', '대화에서'): 4,
#  ('이', '대화에서', '선물에', '대해'): 3,
#  ('화자는', '이', '대화에서', '학교생활에'): 3,
#  ('대화에서', '선물에', '대해', '말했습니다'): 3,
#  ('화자는', '이', '대화에서', '학교'): 3,
#  ('화자는', '이', '대화에서', '선물에'): 3,
#  ('화자는', '이', '대화에서', '가족'): 2,
#  ('이', '대화에서', '건강', '관리를'): 2,
#  ('대화에서', '학교', '생활에', '대해'): 2,
#  ('화자는', '이', '대화에서', '가장'): 2,
#  ('학교', '생활에', '대해', '말했습니다'): 2,
#  ('관리와', '운동에', '대해', '말했습니다'): 2,
#  ('이', '대화에서', '학교생활에', '대해'): 2,
#  ('이', '대화에서', '연애와', '결혼에'): 2,
#  ('아르바이트에', '대해', '이야기를', '나눴습니다'): 2,
#  ('화자는', '이', '대화에서', '결혼과'): 2,
#  ('이', '대화에서', '학교', '생활에'): 2,
#  ('화자는', '이', '대화에서', '부모와'): 2,
#  ('화자는', '이', '대화에서', '현재'): 2,
#  ('대화에서', '학교생활에', '대해', '말했습니다'): 2}
