# %% [markdown]
# # 쓸모없이 끼어들어 있는 단어들

# %% [markdown]
# - 잘 그 잘, 나는 납 나는 : 한 단어를 뛰고 반복되는 단어들
# - 겨 계절은, 겨 경험이 : 자음 반복
# - 너무너무너무 : 공백 없이 붙어서 두 번 이상 반복되는 단어들
# - 너무 먹고 싶 너무 먹고 싶어요 : 짤려서 반복

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
from copy import deepcopy
from transformers import AutoTokenizer
import re
from collections import defaultdict, OrderedDict
from tqdm import tqdm

def make_dataframe(path: str) -> pd.DataFrame:
    """
    Read a json file and return a pandas DataFrame.

    Parameters:
    path (str): Path to the json file.

    Returns:
    pd.DataFrame: DataFrame of the json file.
    """
    # Read the json file
    with open(path, 'r') as file:
        data = json.load(file)

    # Create a DataFrame
    # columns = ['id', 'conversation', 'subject_keyword', 'output']
    df = pd.DataFrame(data)
    df['conversation'] = df['input'].apply(lambda x: x['conversation'])
    df['subject_keyword'] = df['input'].apply(lambda x: x['subject_keyword'])

    # Drop the 'input' column
    df.drop('input', axis=1, inplace=True)

    # Speakers in the conversation
    def find_ordered_speakers(turns):
        speakers = OrderedDict()
        for turn in turns:
            speakers[turn['speaker']] = 0
        return list(speakers.keys())
    
    df['speakers'] = df['conversation'].apply(find_ordered_speakers)

    # Reorder the columns
    df = df[['id', 'conversation', 'subject_keyword', 'speakers', 'output']]

    return df

train_df = make_dataframe('../resource/data/일상대화요약_train.json')
dev_df = make_dataframe('../resource/data/일상대화요약_dev.json')
test_df = make_dataframe('../resource/data/일상대화요약_test.json')
filtered_train_df = make_dataframe('./train.json')
filtered_dev_df = make_dataframe('./dev.json')
filtered_test_df = make_dataframe('./test.json')

# %% [markdown]
# ## 공백 없이 붙어서 두 번 이상 반복되는 단어들

# %%
import re

text = "너무너무너무 재미있어 재미재미있어 하하하하호호호"

# 동일한 단어가 2번 이상 중복되는 패턴 찾기
pattern = r'(\w+)\1+'
matches = re.findall(pattern, text)

print(matches)
# Out:
# ['너무', '재미', '하하', '호']

# %%
# 공백 없이 붙어서 두 번 이상 반복되는 단어들

def find_repeated_words(df:pd.DataFrame, test = False):
    """
    Find repeated words in the conversation. and output
    """

    df = deepcopy(df)

    conversation_word_dict = defaultdict(int)
    output_word_dict = defaultdict(int)

    def find_repeated_words_in_conversation(conversation):
        for turn in conversation:
            repeated_words = re.findall(r'(\w+)\1+', turn['utterance'])
            if repeated_words:
                for word in repeated_words:
                    conversation_word_dict[word] += 1
    
    def find_repeated_words_in_output(output):
        repeated_words = re.findall(r'(\w+)\1+', output)
        if repeated_words:
            for word in repeated_words:
                output_word_dict[word] += 1
    
    df['conversation'].apply(find_repeated_words_in_conversation)
    print("The number of repeated words in conversation :", len(conversation_word_dict))

    if not test:
        df['output'].apply(find_repeated_words_in_output)
        print("The number of repeated words in output :", len(output_word_dict))
        output_word_dict = sorted(output_word_dict.items(), key=lambda x: x[1], reverse=True)
    
    conversation_word_dict = sorted(conversation_word_dict.items(), key=lambda x: x[1], reverse=True)

    return conversation_word_dict, output_word_dict

# %%
conv, output = find_repeated_words(filtered_train_df)
# Out:
# The number of repeated words in conversation : 375
# The number of repeated words in output : 88

# %%
conv2, output2 = find_repeated_words(filtered_dev_df)
conv3, _ = find_repeated_words(filtered_test_df, test=True)
# Out:
# The number of repeated words in conversation : 123
# The number of repeated words in output : 27
# The number of repeated words in conversation : 287

# %%
convs1 = [c[0] for c in conv]
convs2 = [c[0] for c in conv2]
convs3 = [c[0] for c in conv3]

# %%
filtered_train_df[filtered_train_df['output'].apply(lambda x: '너무' in x)]
# Out:
#                                      id  \
# 1    nikluge-2024-일상 대화 요약-train-000002
# 8    nikluge-2024-일상 대화 요약-train-000009
# 15   nikluge-2024-일상 대화 요약-train-000016
# 26   nikluge-2024-일상 대화 요약-train-000027
# 30   nikluge-2024-일상 대화 요약-train-000031
# ..                                  ...
# 465  nikluge-2024-일상 대화 요약-train-000466
# 474  nikluge-2024-일상 대화 요약-train-000475
# 491  nikluge-2024-일상 대화 요약-train-000492
# 493  nikluge-2024-일상 대화 요약-train-000494
# 501  nikluge-2024-일상 대화 요약-train-000502
#
#                                           conversation   subject_keyword  \
# 1    [{'speaker': 'SD2000002', 'utterance': '여행 다닐 ...  [여행 스타일, 숙소, 음식]
# 8    [{'speaker': 'SD2000018', 'utterance': '네. 오늘 ...          [계절, 날씨]
# 15   [{'speaker': 'SD2000039', 'utterance': '먹거리가 코...              [음식]
# 26   [{'speaker': 'SD2000870', 'utterance': '여자가 결혼...              [자식]
# 30   [{'speaker': 'SD2000873', 'utterance': '근데 무릎이...              [건강]
# ..                                                 ...               ...
# 465  [{'speaker': 'SD2100568', 'utterance': '산 사람 마...           [명절 문제]
# 474  [{'speaker': 'SD2110574', 'utterance': '이번에 언니...          [휴가, 여행]
# 491  [{'speaker': 'SD2100585', 'utterance': '그리고 지금...              [결혼]
# 493  [{'speaker': 'SD2100586', 'utterance': '근데 개념을...            [대안학교]
# 501  [{'speaker': 'SD2100596', 'utterance': 'compan...   [company-name5]
#
#                    speakers                                             output
# 1    [SD2000002, SD2000001]  두 화자는 이 대화에서 쇼핑하기, 숙소, 음식 등 각자 선호하는 여행 스타일에 대해...
# 8    [SD2000018, SD2000017]  두 화자는 이 대화에서 추위와 더위 중에 더 많이 타는 것과 선호하는 계절과 날씨가...
# 15   [SD2000039, SD2000038]  두 화자는 이 대화에서 할머니와 엄마가 해주셨던 음식 중에서 지금은 먹을 수 없지만...
# 26   [SD2000870, SD2000869]  두 화자는 이 대화에서 자식을 낳는 것에 대해 말했습니다. SD2000869는 본인...
# 30   [SD2000873, SD2000874]  두 화자는 이 대화에서 배우자의 건강에 대해 말했습니다. SD2000873은 건강 ...
# ..                      ...                                                ...
# 465  [SD2100568, SD2100567]  두 화자는 이 대화에서 명절 문제에 관한 대화를 했습니다. SD2100568은 제사...
# 474  [SD2110574, SD2100573]  두 화자는 이 대화에서 여행 휴가지에 관해 이야기했습니다. SD2110574는 SD...
# 491  [SD2100585, SD2100586]  두 화자는 이 대화에서 젊은 세대를 중심으로 일어나고 있는 비혼주의 확산 현상에 대...
# 493  [SD2100586, SD2100585]  두 화자는 이 대화에서 자녀 양육 방안을 함께 모색했습니다. SD2100586은 안...
# 501  [SD2100596, SD2100595]  두 화자는 이 대화에서 유명 유튜버의 식당 추천과 음식 장사의 성공 요인에 대해서 ...
#
# [81 rows x 5 columns]

# %% [markdown]
# ## 짤려서 반복

# %%
import re

text = "너무 먹고 싶 너무 먹고 싶어요"

# 단어나 구절이 반복되는 패턴 찾기
pattern = r'(\b\w+(?:\s\w+)*)\s\1'
matches = re.findall(pattern, text)

print(matches)
# Out:
# ['너무 먹고 싶']

# %%
def find_repeated_phrases(df:pd.DataFrame, test = False):
    """
    Find repeated phrases in the conversation. and output
    """

    df = deepcopy(df)

    conversation_phrase_dict = defaultdict(int)
    output_phrase_dict = defaultdict(int)

    def find_repeated_phrases_in_conversation(conversation):
        for turn in conversation:
            repeated_phrases = re.findall(r'(\b\w+(?:\s\w+)*)\s\1', turn['utterance'])
            if repeated_phrases:
                for phrase in repeated_phrases:
                    conversation_phrase_dict[phrase] += 1
    
    def find_repeated_phrases_in_output(output):
        repeated_phrases = re.findall(r'(\b\w+(?:\s\w+)*)\s\1', output)
        if repeated_phrases:
            for phrase in repeated_phrases:
                output_phrase_dict[phrase] += 1

    df['conversation'].apply(find_repeated_phrases_in_conversation)
    print("The number of repeated phrases in conversation :", len(conversation_phrase_dict))
    conversation_phrase_dict = sorted(conversation_phrase_dict.items(), key=lambda x: x[1], reverse=True)
    print("The number of repeated phrases in conversation that repeated num <= 2 :", len([c for c in conversation_phrase_dict if c[1] <= 2]))

    if not test:
        df['output'].apply(find_repeated_phrases_in_output)
        print("The number of repeated phrases in output :", len(output_phrase_dict))
        output_phrase_dict = sorted(output_phrase_dict.items(), key=lambda x: x[1], reverse=True)

    return conversation_phrase_dict, output_phrase_dict

# %%
conv, output = find_repeated_phrases(filtered_train_df)
conv2, output2 = find_repeated_phrases(filtered_dev_df)
conv3, _ = find_repeated_phrases(filtered_test_df, test=True)
# Out:
# The number of repeated phrases in conversation : 828
# The number of repeated phrases in conversation that repeated num <= 2 : 752
# The number of repeated phrases in output : 2
# The number of repeated phrases in conversation : 195
# The number of repeated phrases in conversation that repeated num <= 2 : 181
# The number of repeated phrases in output : 1
# The number of repeated phrases in conversation : 639
# The number of repeated phrases in conversation that repeated num <= 2 : 574

# %% [markdown]
# - 많이 뽑히는 것은 이유가 있는 경우(자주 쓰이는 표현) 일 수 있음
# - 그러므로, 이런 경우는 정성적인 분석이 필요하고
# - 그렇지 않은 적게 뽑히는 것은 예외일 가능성이 높으므로 모두 1개로 통일 (2개 이하)
#     - train : 752 / dev : 181 / test : 574

# %%
text = " 그때 너무 긴장하고 발표 긴장하고 발표 연습"
re.sub(r'긴장하고 발표 긴장하고 발표', '긴장하고 발표', text)
# Out:
# ' 그때 너무 긴장하고 발표 연습'

# %%
a= '긴장하고 발표'
re.search(rf'{a} {a}', text)
# Out:
# <re.Match object; span=(7, 22), match='긴장하고 발표 긴장하고 발표'>

# %%
conv
# Out:
# [('가', 62),
#  ('다', 29),
#  ('이', 28),
#  ('있', 26),
#  ('나', 22),
#  ('하', 21),
#  ('거', 13),
#  ('먹', 12),
#  ('내', 10),
#  ('없', 9),
#  ('사', 9),
#  ('너', 9),
#  ('해', 8),
#  ('저', 8),
#  ('유', 7),
#  ('대', 7),
#  ('시', 7),
#  ('요', 7),
#  ('일', 7),
#  ('그래', 6),
#  ('많', 6),
#  ('했', 6),
#  ('고', 6),
#  ('주', 6),
#  ('제', 5),
#  ('학', 5),
#  ('원', 5),
#  ('여', 5),
#  ('자', 5),
#  ('생', 5),
#  ('한', 5),
#  ('같', 4),
#  ('건', 4),
#  ('보', 4),
#  ('올', 4),
#  ('약', 4),
#  ('지', 4),
#  ('그렇', 4),
#  ('우', 4),
#  ('입', 4),
#  ('얼', 4),
#  ('매', 4),
#  ('거기', 4),
#  ('외', 4),
#  ('집', 4),
#  ('맞', 4),
#  ('않', 4),
#  ('되', 4),
#  ('우리', 4),
#  ('들', 3),
#  ('영', 3),
#  ('재료', 3),
#  ('그냥', 3),
#  ('엄마', 3),
#  ('재', 3),
#  ('몇', 3),
#  ('여름', 3),
#  ('세', 3),
#  ('중', 3),
#  ('인', 3),
#  ('별', 3),
#  ('강', 3),
#  ('3', 3),
#  ('한 명', 3),
#  ('언니', 3),
#  ('친', 3),
#  ('어디', 3),
#  ('신', 3),
#  ('마', 3),
#  ('쪼금', 3),
#  ('시국이', 3),
#  ('언', 3),
#  ('취', 3),
#  ('고양이', 3),
#  ('예', 3),
#  ('그거', 3),
#  ('맛있', 2),
#  ('정도', 2),
#  ('단', 2),
#  ('살', 2),
#  ('코로나 때문에', 2),
#  ('한국', 2),
#  ('구', 2),
#  ('또 그러고', 2),
#  ('아이', 2),
#  ('꽃', 2),
#  ('애들', 2),
#  ('진', 2),
#  ('물', 2),
#  ('있으', 2),
#  ('말', 2),
#  ('부', 2),
#  ('끝', 2),
#  ('공', 2),
#  ('실', 2),
#  ('걷', 2),
#  ('중국', 2),
#  ('계', 2),
#  ('부분', 2),
#  ('모르', 2),
#  ('당', 2),
#  ('남', 2),
#  ('날', 2),
#  ('추', 2),
#  ('그때', 2),
#  ('기', 2),
#  ('습', 2),
#  ('더', 2),
#  ('저희', 2),
#  ('육아', 2),
#  ('병', 2),
#  ('선', 2),
#  ('요즘', 2),
#  ('지금', 2),
#  ('안 해', 2),
#  ('엄', 2),
#  ('현', 2),
#  ('갖', 2),
#  ('있었', 2),
#  ('옷', 2),
#  ('자기', 2),
#  ('좋아', 2),
#  ('개인', 2),
#  ('전', 2),
#  ('키', 2),
#  ('초', 2),
#  ('식', 2),
#  ('찍', 2),
#  ('화장실', 2),
#  ('미', 2),
#  ('키우', 2),
#  ('방', 2),
#  ('것', 2),
#  ('카페', 2),
#  ('게', 2),
#  ('아니', 2),
#  ('괌', 2),
#  ('경주', 2),
#  ('100', 2),
#  ('멀', 2),
#  ('친구', 2),
#  ('미녀와 야수', 2),
#  ('과', 2),
#  ('영화', 2),
#  ('커', 2),
#  ('런닝맨', 2),
#  ('수', 2),
#  ('얘기', 2),
#  ('이름', 2),
#  ('장', 2),
#  ('때', 2),
#  ('의', 2),
#  ('안', 2),
#  ('외국', 2),
#  ('뽑', 2),
#  ('적', 1),
#  ('났', 1),
#  ('된장찌개', 1),
#  ('제주', 1),
#  ('버터 비어', 1),
#  ('가 보', 1),
#  ('터키', 1),
#  ('꿀', 1),
#  ('눈', 1),
#  ('드시', 1),
#  ('거인이었', 1),
#  ('깊', 1),
#  ('두릅', 1),
#  ('들깨 칼국수', 1),
#  ('뭐가 유명합니다', 1),
#  ('양념', 1),
#  ('술빵', 1),
#  ('알았', 1),
#  ('며칠 전에', 1),
#  ('너무 먹고 싶', 1),
#  ('거래처', 1),
#  ('방 하나 부엌 하나', 1),
#  ('취미', 1),
#  ('첫', 1),
#  ('얘', 1),
#  ('헌 집', 1),
#  ('바', 1),
#  ('치즈타르트', 1),
#  ('아쉽', 1),
#  ('주님 주시면', 1),
#  ('세 명', 1),
#  ('너무 싫', 1),
#  ('이쁘긴 한데', 1),
#  ('바래', 1),
#  ('누구', 1),
#  ('한 해', 1),
#  ('은', 1),
#  ('좋은 학교', 1),
#  ('제가 지', 1),
#  ('대해', 1),
#  ('편집을 하', 1),
#  ('대학을 가고 나서', 1),
#  ('민', 1),
#  ('여기 너무', 1),
#  ('어려워', 1),
#  ('이외', 1),
#  ('거북이', 1),
#  ('결혼', 1),
#  ('이번에는 지난번보다 더 맛있는 케이크', 1),
#  ('봄', 1),
#  ('쑥', 1),
#  ('준비해 둔', 1),
#  ('여름 말고', 1),
#  ('걸으면', 1),
#  ('합', 1),
#  ('수학', 1),
#  ('관심받', 1),
#  ('오형', 1),
#  ('탐구형', 1),
#  ('저희 아이들', 1),
#  ('두 살', 1),
#  ('엄마 사랑해', 1),
#  ('들어', 1),
#  ('5대 암', 1),
#  ('의료보험제', 1),
#  ('지역가입자 보험 같은 경우는', 1),
#  ('한려', 1),
#  ('딱히 이런', 1),
#  ('재밌', 1),
#  ('옛', 1),
#  ('노', 1),
#  ('염', 1),
#  ('다 못 먹', 1),
#  ('대다', 1),
#  ('어렸을 때', 1),
#  ('보충제', 1),
#  ('파우치 형태', 1),
#  ('있어', 1),
#  ('이런 거', 1),
#  ('대구에도 갈 곳이 많고', 1),
#  ('피시방 알바를', 1),
#  ('연애', 1),
#  ('연', 1),
#  ('4', 1),
#  ('채', 1),
#  ('했다', 1),
#  ('처음에는 인공', 1),
#  ('조심', 1),
#  ('기름', 1),
#  ('삼촌', 1),
#  ('필요하', 1),
#  ('여행', 1),
#  ('장가계', 1),
#  ('가구', 1),
#  ('진행', 1),
#  ('5월', 1),
#  ('도서', 1),
#  ('썼다가 선글라스', 1),
#  ('한 30분', 1),
#  ('시간', 1),
#  ('여름 지나고', 1),
#  ('그다음에', 1),
#  ('걷기', 1),
#  ('고등학', 1),
#  ('달려가', 1),
#  ('굴곡', 1),
#  ('1', 1),
#  ('친구 집에', 1),
#  ('소', 1),
#  ('향', 1),
#  ('일용', 1),
#  ('임', 1),
#  ('도로', 1),
#  ('적었던 거 같', 1),
#  ('또한 가을에서 주는', 1),
#  ('빨리 봄이 오면 좋겠다', 1),
#  ('봄이 왔다', 1),
#  ('여름에 할 수 있', 1),
#  ('분야', 1),
#  ('피', 1),
#  ('휴', 1),
#  ('긍정', 1),
#  ('태양', 1),
#  ('배를 타', 1),
#  ('내쉬', 1),
#  ('2', 1),
#  ('하다 보니까', 1),
#  ('원래', 1),
#  ('좋은', 1),
#  ('감독님', 1),
#  ('배우', 1),
#  ('정인이라는 딸이랑', 1),
#  ('거 이런', 1),
#  ('그러니까 순풍을 타고', 1),
#  ('보기', 1),
#  ('뭐니', 1),
#  ('운동이다 보니까', 1),
#  ('졌', 1),
#  ('한 마리씩', 1),
#  ('새', 1),
#  ('하니', 1),
#  ('오빠 조금 믿어봐', 1),
#  ('이래', 1),
#  ('너무', 1),
#  ('여보 고마워요', 1),
#  ('군', 1),
#  ('아들', 1),
#  ('등', 1),
#  ('아들은 안 키워봤지만', 1),
#  ('볼', 1),
#  ('잠', 1),
#  ('봐', 1),
#  ('에이형', 1),
#  ('뭐라 그러지', 1),
#  ('그런 면', 1),
#  ('상대', 1),
#  ('데이트라', 1),
#  ('큰 거', 1),
#  ('면', 1),
#  ('남녀', 1),
#  ('여행 동호회', 1),
#  ('혈액형', 1),
#  ('말투 같은 거 이런 거를', 1),
#  ('재수생', 1),
#  ('좀 원한을', 1),
#  ('이유도 없이', 1),
#  ('받', 1),
#  ('빨리 가자고', 1),
#  ('시어', 1),
#  ('답답', 1),
#  ('하다 말겠지', 1),
#  ('씬', 1),
#  ('왜 그러지', 1),
#  ('제 돈을', 1),
#  ('1000원 500원', 1),
#  ('이해는 하겠는데', 1),
#  ('법', 1),
#  ('실력', 1),
#  ('대학교 들어가', 1),
#  ('꼭 시', 1),
#  ('겪', 1),
#  ('일터 집', 1),
#  ('내가 잘 안 먹으니까', 1),
#  ('지냈', 1),
#  ('외글', 1),
#  ('왜', 1),
#  ('지금 시니어', 1),
#  ('몰', 1),
#  ('그다', 1),
#  ('넘', 1),
#  ('운', 1),
#  ('한강', 1),
#  ('생활', 1),
#  ('수영', 1),
#  ('아버', 1),
#  ('주도', 1),
#  ('그냥 이런', 1),
#  ('내 나', 1),
#  ('1억 원', 1),
#  ('한 발', 1),
#  ('하던 일만 할 수', 1),
#  ('가지', 1),
#  ('요 근래에', 1),
#  ('또 이', 1),
#  ('정', 1),
#  ('마동', 1),
#  ('그러니까 영', 1),
#  ('며', 1),
#  ('축구', 1),
#  ('축', 1),
#  ('지리산', 1),
#  ('따', 1),
#  ('해결할 수', 1),
#  ('현금', 1),
#  ('기특', 1),
#  ('은사님', 1),
#  ('받았', 1),
#  ('학교 다닐 때', 1),
#  ('할 수', 1),
#  ('이거 뭐냐', 1),
#  ('한식', 1),
#  ('부비', 1),
#  ('아닌 거', 1),
#  ('싶', 1),
#  ('봤어', 1),
#  ('한 바퀴씩', 1),
#  ('반', 1),
#  ('아기들', 1),
#  ('게으르', 1),
#  ('전단', 1),
#  ('모델 하우스에서', 1),
#  ('옛날 일', 1),
#  ('쇼', 1),
#  ('출근만 했다가', 1),
#  ('아르', 1),
#  ('나 같', 1),
#  ('자체', 1),
#  ('아줌마', 1),
#  ('50', 1),
#  ('투', 1),
#  ('이대', 1),
#  ('패', 1),
#  ('부산', 1),
#  ('시리즈', 1),
#  ('순간', 1),
#  ('백업', 1),
#  ('잘 나가고', 1),
#  ('국내', 1),
#  ('비인기 종목들', 1),
#  ('철인 3종 경기', 1),
#  ('내가 어느', 1),
#  ('요런 것들', 1),
#  ('울며 겨자 먹기로', 1),
#  ('저희 학교가', 1),
#  ('동', 1),
#  ('중요', 1),
#  ('있을 거', 1),
#  ('버즈', 1),
#  ('어찌', 1),
#  ('캠', 1),
#  ('앵', 1),
#  ('안 된다', 1),
#  ('고양', 1),
#  ('치열하여', 1),
#  ('쥐', 1),
#  ('이모 왔다', 1),
#  ('작', 1),
#  ('2년', 1),
#  ('키워', 1),
#  ('맹인', 1),
#  ('맹', 1),
#  ('혹시', 1),
#  ('일어', 1),
#  ('폐기', 1),
#  ('그리', 1),
#  ('매니저', 1),
#  ('셨', 1),
#  ('항상 산', 1),
#  ('테이', 1),
#  ('봤', 1),
#  ('개', 1),
#  ('꺼', 1),
#  ('하나 주세요 저거', 1),
#  ('닮', 1),
#  ('보양식', 1),
#  ('나는 일단', 1),
#  ('분위기', 1),
#  ('10', 1),
#  ('시험', 1),
#  ('몇 시부터 몇 시까지 무엇을 하고', 1),
#  ('담백', 1),
#  ('먹어', 1),
#  ('가 보고 싶은', 1),
#  ('형제 자매', 1),
#  ('시시도 안 해봤고', 1),
#  ('솔', 1),
#  ('쪼끔 힘들었던 나라', 1),
#  ('피해', 1),
#  ('어라', 1),
#  ('둘 다', 1),
#  ('특', 1),
#  ('께', 1),
#  ('재배 하', 1),
#  ('굉장', 1),
#  ('그릇', 1),
#  ('닭강', 1),
#  ('탕수육', 1),
#  ('업', 1),
#  ('살이 찌다 보니까', 1),
#  ('북해도', 1),
#  ('서산', 1),
#  ('1000원', 1),
#  ('산', 1),
#  ('13년', 1),
#  ('홀', 1),
#  ('하롱베이', 1),
#  ('그때 너랑', 1),
#  ('영화관', 1),
#  ('덴마크', 1),
#  ('융통성 있게', 1),
#  ('벚', 1),
#  ('나이가 먹으면은', 1),
#  ('슬', 1),
#  ('심혈', 1),
#  ('심', 1),
#  ('고거', 1),
#  ('하루 정도는', 1),
#  ('60 다', 1),
#  ('홍삼', 1),
#  ('여섯 박스', 1),
#  ('이것', 1),
#  ('우리 집', 1),
#  ('뭔 잘못', 1),
#  ('자다', 1),
#  ('강아', 1),
#  ('사료', 1),
#  ('참외', 1),
#  ('친구 투', 1),
#  ('열 가', 1),
#  ('밥', 1),
#  ('학업', 1),
#  ('실습', 1),
#  ('쉬', 1),
#  ('득표', 1),
#  ('만들었', 1),
#  ('악마 조금', 1),
#  ('다스 베이더', 1),
#  ('욕망', 1),
#  ('너무 어릴 때', 1),
#  ('결과', 1),
#  ('우리 봉사단', 1),
#  ('한 사람', 1),
#  ('안 그래도', 1),
#  ('둘', 1),
#  ('결혼해', 1),
#  ('어머니', 1),
#  ('형제 중에', 1),
#  ('이만', 1),
#  ('집에 또', 1),
#  ('형', 1),
#  ('제 동생이', 1),
#  ('첫인상', 1),
#  ('이랬', 1),
#  ('설문', 1),
#  ('어느 정도', 1),
#  ('경호', 1),
#  ('괜', 1),
#  ('해 봐', 1),
#  ('싸', 1),
#  ('벤츠', 1),
#  ('능', 1),
#  ('여기 게 마음에 든다', 1),
#  ('호', 1),
#  ('채널', 1),
#  ('키우면', 1),
#  ('돈', 1),
#  ('저에', 1),
#  ('장애', 1),
#  ('침', 1),
#  ('긴장하고 발표', 1),
#  ('밤', 1),
#  ('성', 1),
#  ('받았었', 1),
#  ('어떤 선물이었', 1),
#  ('생명', 1),
#  ('보시', 1),
#  ('2회', 1),
#  ('열', 1),
#  ('뽕', 1),
#  ('붐', 1),
#  ('부럽', 1),
#  ('만족', 1),
#  ('걱정', 1),
#  ('대학', 1),
#  ('궁금', 1),
#  ('팬', 1),
#  ('혈', 1),
#  ('혈액', 1),
#  ('거 예쁜', 1),
#  ('안에', 1),
#  ('쓸', 1),
#  ('윗', 1),
#  ('공감 능', 1),
#  ('학교 다닐 때는', 1),
#  ('틀어', 1),
#  ('삼', 1),
#  ('삼시', 1),
#  ('10분 있', 1),
#  ('선수', 1),
#  ('한라산', 1),
#  ('갔던 곳 모두 좋았지만', 1),
#  ('내가 생', 1),
#  ('안 보', 1),
#  ('역', 1),
#  ('높', 1),
#  ('받아', 1),
#  ('한 살', 1),
#  ('난 아무래도', 1),
#  ('학교 나가고', 1),
#  ('젊', 1),
#  ('안 했으니까', 1),
#  ('애', 1),
#  ('데', 1),
#  ('안 할', 1),
#  ('강아지가 이', 1),
#  ('주인이 무지하니까', 1),
#  ('쉽지 않아', 1),
#  ('우리 아들', 1),
#  ('응', 1),
#  ('마오가 있으니까', 1),
#  ('수술 하고 나서는', 1),
#  ('오리', 1),
#  ('닭도리', 1),
#  ('수요일', 1),
#  ('그냥 바로 포장하면은 냉장고에 다 넣어 놓고', 1),
#  ('메', 1),
#  ('케이', 1),
#  ('음악', 1),
#  ('청소년', 1),
#  ('훨', 1),
#  ('협재', 1),
#  ('홈', 1),
#  ('샀으니', 1),
#  ('잔', 1),
#  ('집이', 1),
#  ('제트', 1),
#  ('멕시코 식당', 1),
#  ('각시', 1),
#  ('화덕피자', 1),
#  ('롤', 1),
#  ('물류', 1),
#  ('코인', 1),
#  ('매년 정주행', 1),
#  ('동백꽃', 1),
#  ('온천', 1),
#  ('놀', 1),
#  ('운동', 1),
#  ('하자', 1),
#  ('고용', 1),
#  ('본원 통화', 1),
#  ('선물', 1),
#  ('경', 1),
#  ('그렇게 보면', 1),
#  ('상', 1),
#  ('소형 평', 1),
#  ('화', 1),
#  ('돈 때문', 1),
#  ('안 들', 1),
#  ('네가 아까', 1),
#  ('한 분', 1),
#  ('세 시간', 1),
#  ('쫄', 1),
#  ('10000원', 1),
#  ('두 명', 1),
#  ('그런 거', 1),
#  ('부모님들', 1),
#  ('만', 1),
#  ('홈플러스', 1),
#  ('스타필드', 1),
#  ('배달', 1),
#  ('물품', 1),
#  ('추워지면 바로', 1),
#  ('1년', 1),
#  ('강릉', 1),
#  ('계획', 1),
#  ('다른 군데 또 가고', 1),
#  ('한 끼도', 1),
#  ('운전에 너무', 1),
#  ('틀', 1),
#  ('힘들', 1),
#  ('폰', 1),
#  ('일 잘', 1),
#  ('거 그런', 1),
#  ('1 2시', 1),
#  ('홈플러스 건너편', 1),
#  ('구워 먹는 그런', 1),
#  ('2 3명', 1),
#  ('번데기', 1),
#  ('좀 한번', 1),
#  ('분', 1),
#  ('정책', 1),
#  ('테크', 1),
#  ('상한', 1),
#  ('어떤 큰', 1),
#  ('그런', 1),
#  ('100만 원', 1),
#  ('똑같', 1),
#  ('잘못', 1),
#  ('내가 뭔', 1),
#  ('주점', 1),
#  ('걸어 보는 건', 1),
#  ('삐끗', 1),
#  ('캡', 1),
#  ('조금', 1),
#  ('한 군데', 1),
#  ('있지 않나', 1),
#  ('한남', 1),
#  ('접', 1),
#  ('여러 분야의 사람들도 만나보고 나랑 다른 친구들도 많이 사귀어보고', 1),
#  ('들었', 1),
#  ('신나', 1),
#  ('도서관 중앙', 1),
#  ('사케', 1),
#  ('순댓국', 1),
#  ('비린 것도', 1),
#  ('가성비', 1),
#  ('고기류', 1),
#  ('좋아하고 찌개', 1),
#  ('짤막', 1),
#  ('가족이', 1),
#  ('뒤집어', 1),
#  ('한 달 이상은', 1),
#  ('그런 것들이 좀', 1),
#  ('멀리', 1),
#  ('좀 화', 1),
#  ('드라', 1),
#  ('리메이크', 1),
#  ('그분', 1),
#  ('김광석 씨', 1),
#  ('많았', 1),
#  ('면접', 1),
#  ('인터넷 뉴스 같은 데서는 저녁 7시에서 8시부터는 금식을 하라고', 1),
#  ('강박적', 1),
#  ('다시 한번', 1),
#  ('여기 갔다가', 1),
#  ('맛있는 회', 1),
#  ('가고 싶', 1),
#  ('행신', 1),
#  ('떡갈비', 1),
#  ('그래 그러면', 1),
#  ('쑥 맛 아이스크림이랑', 1),
#  ('존경한', 1),
#  ('혹', 1),
#  ('현미', 1),
#  ('전화로', 1),
#  ('중간', 1),
#  ('있는', 1),
#  ('양상추', 1),
#  ('해 먹', 1),
#  ('다이어트', 1),
#  ('돈도 돈이지만 가족처럼 해 줬을 때', 1),
#  ('희', 1),
#  ('투잡', 1),
#  ('아무', 1),
#  ('3시 반', 1),
#  ('다이어트 할 때', 1),
#  ('병행', 1),
#  ('근처', 1),
#  ('다이어트를 떠나서', 1),
#  ('뱃', 1),
#  ('땡', 1),
#  ('과일 같은 거는', 1),
#  ('사과', 1),
#  ('자기 모든 것이 딱', 1),
#  ('평안', 1),
#  ('손', 1),
#  ('위험', 1),
#  ('얻', 1),
#  ('에프', 1),
#  ('비싸지', 1),
#  ('타', 1),
#  ('기회비용', 1),
#  ('어불', 1),
#  ('name 씨', 1),
#  ('절', 1),
#  ('정말 자연적으로 다', 1),
#  ('1장', 1),
#  ('메롱', 1),
#  ('산책', 1),
#  ('식단', 1),
#  ('더러운 게 티가 잘 안 나고', 1),
#  ('길', 1),
#  ('컸', 1),
#  ('저녁 때', 1),
#  ('돈가스', 1),
#  ('숯', 1),
#  ('풀', 1),
#  ('너 이럴', 1),
#  ('닭껍질', 1),
#  ('내가 봤', 1),
#  ('홍', 1),
#  ('셔플', 1),
#  ('보조 어떤', 1),
#  ('어디 구', 1),
#  ('어디 동', 1),
#  ('고기', 1),
#  ('사이에', 1),
#  ('쉴세 없이', 1),
#  ('김', 1),
#  ('지난 8월 달에', 1),
#  ('울렁', 1),
#  ('배', 1),
#  ('검은', 1),
#  ('팥', 1),
#  ('울부', 1),
#  ('동물', 1),
#  ('문어', 1),
#  ('일하는 스트레스', 1),
#  ('부담스럽', 1),
#  ('배려를 해 주면 좋은데 그게 어렵더라고', 1),
#  ('내가 유', 1),
#  ('나이', 1),
#  ('발', 1),
#  ('호텔 델루나', 1),
#  ('드', 1),
#  ('새별오름', 1),
#  ('풍경', 1),
#  ('바다', 1),
#  ('참돔', 1),
#  ('해운대', 1),
#  ('분위', 1),
#  ('그렇지 겨울 바다', 1),
#  ('큰 형님이', 1),
#  ('고래', 1),
#  ('쳐다보고 내렸다가', 1),
#  ('유럽', 1),
#  ('굴 농', 1),
#  ('샷', 1),
#  ('내려', 1),
#  ('핸', 1),
#  ('대면', 1),
#  ('2학년', 1),
#  ('최저등', 1),
#  ('강박', 1),
#  ('취업', 1),
#  ('만화책에', 1),
#  ('전기', 1),
#  ('고리', 1),
#  ('차', 1),
#  ('보장', 1),
#  ('효', 1),
#  ('한 번', 1),
#  ('했었', 1),
#  ('빵', 1),
#  ('딸기', 1),
#  ('딱', 1),
#  ('귀엽', 1),
#  ('굉', 1),
#  ('최근', 1),
#  ('name2', 1),
#  ('염증', 1),
#  ('묘', 1),
#  ('하루', 1),
#  ('이 년', 1),
#  ('안양', 1),
#  ('언덕', 1),
#  ('경험', 1),
#  ('어떤 부분', 1),
#  ('관', 1),
#  ('참치', 1),
#  ('성게알', 1),
#  ('1해', 1),
#  ('두 병', 1)]

# %%
output
# Out:
# [('두루', 1), ('깜짝', 1)]

# %%
conv2
# Out:
# [('있', 8),
#  ('다', 6),
#  ('하', 6),
#  ('먹', 5),
#  ('기', 5),
#  ('이', 5),
#  ('언니', 4),
#  ('해', 3),
#  ('보', 3),
#  ('저', 3),
#  ('한 살', 3),
#  ('사', 3),
#  ('생', 3),
#  ('1', 3),
#  ('말', 2),
#  ('자', 2),
#  ('산', 2),
#  ('가', 2),
#  ('설', 2),
#  ('인', 2),
#  ('최', 2),
#  ('입', 2),
#  ('약', 2),
#  ('매', 2),
#  ('반', 2),
#  ('주', 2),
#  ('그래', 2),
#  ('많', 2),
#  ('미국', 2),
#  ('공', 2),
#  ('음식', 2),
#  ('잃', 2),
#  ('유산', 1),
#  ('안 했', 1),
#  ('음식을 먹으실 때', 1),
#  ('평', 1),
#  ('찾게 되', 1),
#  ('오랜만에 도가니', 1),
#  ('건물 지어가지고', 1),
#  ('인테리어', 1),
#  ('능이', 1),
#  ('자연', 1),
#  ('식', 1),
#  ('맛', 1),
#  ('그런 게', 1),
#  ('문', 1),
#  ('비서', 1),
#  ('챙', 1),
#  ('탈', 1),
#  ('후', 1),
#  ('혹', 1),
#  ('우리', 1),
#  ('야간 알바', 1),
#  ('치', 1),
#  ('떡볶이', 1),
#  ('그렇게 하면', 1),
#  ('거기', 1),
#  ('씁', 1),
#  ('노', 1),
#  ('저 돈', 1),
#  ('네다', 1),
#  ('라', 1),
#  ('뭘 하려면', 1),
#  ('유산균이', 1),
#  ('건강', 1),
#  ('마', 1),
#  ('순간', 1),
#  ('최근에 종영한', 1),
#  ('요즘', 1),
#  ('드라', 1),
#  ('실망도 하고', 1),
#  ('이름', 1),
#  ('쓰이', 1),
#  ('반려묘', 1),
#  ('버', 1),
#  ('개', 1),
#  ('겨울', 1),
#  ('습', 1),
#  ('항', 1),
#  ('무', 1),
#  ('형', 1),
#  ('갱년기가 오면서', 1),
#  ('둘레길', 1),
#  ('자전거', 1),
#  ('전', 1),
#  ('튼튼하', 1),
#  ('반려', 1),
#  ('못', 1),
#  ('키', 1),
#  ('거 같은', 1),
#  ('배', 1),
#  ('워', 1),
#  ('된', 1),
#  ('한 번', 1),
#  ('어떻게 보면은', 1),
#  ('자녀들을 키우면서', 1),
#  ('듣', 1),
#  ('아이', 1),
#  ('다녀왔는데 친구 집에', 1),
#  ('하면', 1),
#  ('가지', 1),
#  ('잠자', 1),
#  ('애들', 1),
#  ('투 에어팟', 1),
#  ('비합', 1),
#  ('대학', 1),
#  ('화', 1),
#  ('뿌', 1),
#  ('마라', 1),
#  ('굳', 1),
#  ('보이', 1),
#  ('있으', 1),
#  ('2세', 1),
#  ('그런 욕심', 1),
#  ('안 되더라', 1),
#  ('표현', 1),
#  ('엄', 1),
#  ('버거', 1),
#  ('나랑 대화가 안', 1),
#  ('이 사람하고', 1),
#  ('1학', 1),
#  ('다음 학기', 1),
#  ('수', 1),
#  ('도와주겠', 1),
#  ('걔', 1),
#  ('단톡', 1),
#  ('단', 1),
#  ('압', 1),
#  ('같고', 1),
#  ('그랬는데', 1),
#  ('잠도 오고 그러니까', 1),
#  ('체육', 1),
#  ('고', 1),
#  ('여수', 1),
#  ('그때', 1),
#  ('빅', 1),
#  ('홈', 1),
#  ('타', 1),
#  ('일으', 1),
#  ('우승', 1),
#  ('재', 1),
#  ('그런 것들', 1),
#  ('그거', 1),
#  ('진', 1),
#  ('상품', 1),
#  ('해대', 1),
#  ('생겨', 1),
#  ('쌓', 1),
#  ('했', 1),
#  ('결재를 받는', 1),
#  ('남자', 1),
#  ('정당하', 1),
#  ('열심히 해서', 1),
#  ('캐니언이', 1),
#  ('그랜드 캐녀', 1),
#  ('문화', 1),
#  ('동부 쪽', 1),
#  ('작', 1),
#  ('옹고', 1),
#  ('고런 쪽', 1),
#  ('산호', 1),
#  ('제주도', 1),
#  ('닮', 1),
#  ('말이', 1),
#  ('미', 1),
#  ('시', 1),
#  ('굉', 1),
#  ('찾', 1),
#  ('나', 1),
#  ('돈', 1),
#  ('콜센', 1),
#  ('너', 1),
#  ('오빠야', 1),
#  ('결혼', 1),
#  ('너희', 1),
#  ('여', 1),
#  ('골', 1),
#  ('젊은', 1),
#  ('한', 1),
#  ('가야 되는데', 1),
#  ('트 드', 1),
#  ('짜잘', 1),
#  ('학교 생', 1),
#  ('꿈', 1),
#  ('사진', 1),
#  ('쿵쾅', 1),
#  ('너무 배가 고파서', 1),
#  ('가족 끼리', 1),
#  ('건', 1),
#  ('부', 1),
#  ('추사랑', 1),
#  ('내 친구', 1),
#  ('예를 들', 1),
#  ('즐기', 1),
#  ('자기들 인생이기 때문에', 1)]

# %%
def find_index_of_repeated_phrases(df:pd.DataFrame, sampled_conv):
    """
    Find index of repeated phrases in the conversation.
    """

    df = deepcopy(df)

    repeated_phrases = sampled_conv
    repeated_phrase_indices = defaultdict(list)

    for idx, row in tqdm(df.iterrows(), total=len(df)):
        for phrase in repeated_phrases:
            pattern = rf'{phrase} {phrase}'
            for turn in row['conversation']:
                if re.search(pattern, turn['utterance']):
                    repeated_phrase_indices[idx].append(phrase)

    return repeated_phrase_indices

# %%
train_repeated_phrase_indices = find_index_of_repeated_phrases(filtered_train_df, [c[0] for c in conv if c[1]<=2])
dev_repeated_phrase_indices = find_index_of_repeated_phrases(filtered_dev_df, [c[0] for c in conv2 if c[1]<=2])
test_repeated_phrase_indices = find_index_of_repeated_phrases(filtered_test_df, [c[0] for c in conv3 if c[1]<=2])
# Out:
#   0%|          | 0/506 [00:00<?, ?it/s]
# 100%|██████████| 506/506 [00:09<00:00, 50.80it/s]
# 100%|██████████| 102/102 [00:00<00:00, 548.47it/s]
# 100%|██████████| 408/408 [00:05<00:00, 78.87it/s]

# %%
train_repeated_phrase_indices
# Out:
# defaultdict(list,
#             {1: ['적'],
#              2: ['났'],
#              5: ['된장찌개'],
#              6: ['맛있', '제주', '버터 비어', '가 보', '터키'],
#              7: ['꿀', '면'],
#              9: ['눈'],
#              10: ['정도', '드시'],
#              12: ['단', '거인이었', '깊'],
#              14: ['살', '두릅', '들깨 칼국수', '뭐가 유명합니다'],
#              15: ['양념', '술빵', '알았', '며칠 전에', '너무 먹고 싶'],
#              16: ['거래처'],
#              17: ['코로나 때문에', '방 하나 부엌 하나', '취미'],
#              18: ['첫', '얘'],
#              19: ['헌 집'],
#              20: ['한국', '바'],
#              23: ['코로나 때문에'],
#              24: ['치즈타르트'],
#              25: ['아쉽'],
#              26: ['주님 주시면', '세 명', '너무 싫', '이쁘긴 한데'],
#              27: ['바래'],
#              28: ['구', '누구'],
#              29: ['한 해'],
#              30: ['또 그러고', '은'],
#              31: ['좋은 학교', '제가 지', '대해'],
#              32: ['편집을 하', '대학을 가고 나서'],
#              33: ['민', '여기 너무'],
#              34: ['어려워', '이외'],
#              38: ['거북이', '결혼', '이번에는 지난번보다 더 맛있는 케이크'],
#              40: ['아이', '아이', '좋아', '장'],
#              42: ['꽃', '봄', '쑥', '준비해 둔', '여름 말고', '걸으면'],
#              43: ['합', '수학'],
#              44: ['애들'],
#              45: ['관심받', '오형'],
#              46: ['진', '탐구형'],
#              48: ['저희 아이들', '두 살', '엄마 사랑해'],
#              50: ['들어', '5대 암', '의료보험제', '지역가입자 보험 같은 경우는'],
#              53: ['한려'],
#              54: ['딱히 이런'],
#              55: ['물', '재밌'],
#              57: ['너무'],
#              60: ['있으', '은', '옛'],
#              61: ['말', '노', '염', '다 못 먹'],
#              63: ['대다'],
#              64: ['어렸을 때'],
#              66: ['보충제', '파우치 형태'],
#              68: ['있어'],
#              69: ['이런 거'],
#              70: ['대구에도 갈 곳이 많고'],
#              71: ['상'],
#              72: ['피시방 알바를', '연애'],
#              73: ['연', '4', '채', '했다'],
#              77: ['부', '처음에는 인공'],
#              78: ['끝', '조심', '기름'],
#              79: ['삼촌'],
#              80: ['필요하'],
#              81: ['여행', '장가계'],
#              82: ['가구', '진행', '5월'],
#              83: ['공', '실', '도서', '썼다가 선글라스'],
#              84: ['안', '한 30분', '시간', '여름 지나고'],
#              85: ['걷', '그다음에', '걷기'],
#              86: ['면'],
#              87: ['면'],
#              88: ['고등학', '달려가'],
#              89: ['굴곡'],
#              90: ['중국', '1'],
#              91: ['친구 집에', '소', '산'],
#              92: ['실', '향'],
#              93: ['일용', '임'],
#              94: ['계',
#               '부분',
#               '도로',
#               '적었던 거 같',
#               '또한 가을에서 주는',
#               '빨리 봄이 오면 좋겠다',
#               '봄이 왔다'],
#              95: ['여름에 할 수 있', '분야', '피', '휴', '긍정', '태양'],
#              97: ['배를 타'],
#              98: ['모르', '내쉬', '면'],
#              99: ['2'],
#              100: ['당', '하다 보니까'],
#              101: ['원래'],
#              102: ['좋은'],
#              103: ['상'],
#              104: ['남'],
#              107: ['감독님', '배우', '정인이라는 딸이랑'],
#              108: ['거 이런'],
#              109: ['그러니까 순풍을 타고', '보기'],
#              110: ['뭐니', '운동이다 보니까', '졌'],
#              111: ['한 마리씩', '새'],
#              112: ['하니', '오빠 조금 믿어봐', '이래', '너무', '여보 고마워요'],
#              113: ['군', '아들', '등'],
#              114: ['말', '아들은 안 키워봤지만', '볼'],
#              115: ['날'],
#              117: ['추'],
#              119: ['잠', '봐'],
#              120: ['에이형', '뭐라 그러지', '그런 면', '상대'],
#              121: ['그때'],
#              124: ['데이트라', '데'],
#              125: ['의', '큰 거', '면', '남녀', '여행 동호회'],
#              126: ['혈액형', '말투 같은 거 이런 거를', '재수생', '좀 원한을', '이유도 없이', '받'],
#              127: ['빨리 가자고', '시어', '답답'],
#              128: ['하다 말겠지'],
#              130: ['게'],
#              131: ['씬'],
#              133: ['기', '왜 그러지', '제 돈을', '1000원 500원'],
#              134: ['이해는 하겠는데'],
#              136: ['습', '더'],
#              137: ['저희'],
#              138: ['육아'],
#              139: ['구', '부', '병', '법'],
#              140: ['선', '요즘'],
#              141: ['구', '실력', '대학교 들어가', '꼭 시'],
#              144: ['물', '지금'],
#              145: ['부분', '겪'],
#              146: ['꽃', '일터 집', '내가 잘 안 먹으니까'],
#              147: ['지냈', '외글'],
#              150: ['안 해', '왜', '지금 시니어'],
#              151: ['몰'],
#              152: ['그다', '넘'],
#              153: ['의'],
#              154: ['운'],
#              155: ['습', '엄', '한강', '생활', '수영'],
#              156: ['아버', '주도', '그냥 이런'],
#              157: ['내 나'],
#              158: ['현', '1억 원', '한 발'],
#              159: ['하던 일만 할 수', '가지'],
#              160: ['갖', '요 근래에'],
#              161: ['또 이'],
#              162: ['정'],
#              163: ['의'],
#              164: ['있었', '옷'],
#              165: ['마동', '그러니까 영'],
#              166: ['자기', '며'],
#              167: ['좋아', '축구', '축'],
#              168: ['지리산'],
#              169: ['따'],
#              170: ['해결할 수'],
#              171: ['현금', '기특'],
#              172: ['은사님', '받았'],
#              173: ['개인', '운', '학교 다닐 때', '조금'],
#              174: ['말', '있었', '전', '할 수', '이거 뭐냐', '한식'],
#              175: ['저희', '부비'],
#              176: ['키', '아닌 거', '싶', '봤어'],
#              177: ['한 바퀴씩'],
#              180: ['반', '아기들'],
#              181: ['끝', '공', '갖', '게으르', '전단', '모델 하우스에서', '옛날 일', '쇼'],
#              182: ['초', '식', '출근만 했다가', '아르', '나 같', '자체', '아줌마', '50'],
#              184: ['투'],
#              185: ['찍', '이대', '패'],
#              186: ['진'],
#              187: ['화장실', '부산', '시리즈'],
#              188: ['순간', '백업', '잘 나가고', '국내', '상'],
#              189: ['자기',
#               '미',
#               '비인기 종목들',
#               '철인 3종 경기',
#               '내가 어느',
#               '요런 것들',
#               '울며 겨자 먹기로'],
#              190: ['전', '미', '저희 학교가'],
#              191: ['동'],
#              192: ['당', '중요'],
#              193: ['있을 거', '버즈'],
#              194: ['구'],
#              195: ['어찌', '캠'],
#              196: ['앵', '안 된다'],
#              197: ['고양'],
#              198: ['치열하여'],
#              200: ['쥐', '이모 왔다', '작', '2년', '키워'],
#              201: ['맹인', '맹'],
#              204: ['혹시', '일어'],
#              206: ['폐기', '그리'],
#              207: ['추', '매니저', '셨'],
#              208: ['항상 산', '테이', '산'],
#              209: ['키우', '봤', '개'],
#              210: ['방', '꺼'],
#              212: ['하나 주세요 저거'],
#              214: ['닮'],
#              215: ['것', '보양식'],
#              216: ['나는 일단', '분위기'],
#              217: ['10', '시험', '몇 시부터 몇 시까지 무엇을 하고'],
#              219: ['더', '것', '카페', '담백', '먹어'],
#              221: ['가 보고 싶은'],
#              222: ['게'],
#              223: ['은', '형제 자매'],
#              224: ['아니', '시시도 안 해봤고'],
#              225: ['솔'],
#              226: ['쪼끔 힘들었던 나라'],
#              227: ['피해'],
#              228: ['어라'],
#              229: ['둘 다'],
#              230: ['특', '께'],
#              231: ['남', '아니', '재배 하'],
#              232: ['굉장', '그릇'],
#              233: ['닭강', '탕수육', '업', '살이 찌다 보니까'],
#              235: ['북해도', '서산'],
#              236: ['괌', '1000원', '산', '13년'],
#              237: ['애들', '홀', '하롱베이'],
#              238: ['화장실', '그때 너랑', '영화관'],
#              239: ['계', '경주', '덴마크', '융통성 있게', '벚', '계획'],
#              240: ['안 해', '나이가 먹으면은', '슬', '심혈', '심'],
#              241: ['100', '고거', '하루 정도는', '60 다', '홍삼', '여섯 박스', '이것'],
#              242: ['우리 집', '뭔 잘못', '자다'],
#              243: ['멀', '강아', '사료', '참외'],
#              244: ['친구', '새', '새', '친구 투'],
#              245: ['키', '의'],
#              248: ['열 가'],
#              249: ['좋아', '미녀와 야수', '미녀와 야수', '밥'],
#              250: ['과', '학업'],
#              251: ['실습', '쉬'],
#              252: ['득표', '만들었', '악마 조금', '다스 베이더', '욕망'],
#              253: ['영화'],
#              254: ['너무 어릴 때', '결과'],
#              255: ['우리 봉사단', '한 사람'],
#              260: ['안 그래도', '둘', '결혼해', '어머니'],
#              261: ['커', '형제 중에', '이만', '집에 또', '형', '제 동생이'],
#              262: ['첫인상'],
#              263: ['이랬', '설문', '어느 정도'],
#              265: ['현', '게', '경호', '괜', '해 봐', '싸', '벤츠'],
#              266: ['적'],
#              267: ['지금', '의', '능'],
#              268: ['여기 게 마음에 든다', '데'],
#              269: ['호'],
#              270: ['구'],
#              272: ['채널', '키우면'],
#              273: ['돈', '저에'],
#              275: ['식', '장애', '침'],
#              276: ['긴장하고 발표'],
#              279: ['밤'],
#              280: ['방', '성'],
#              282: ['받았었', '어떤 선물이었'],
#              283: ['생명'],
#              284: ['살', '보시', '2회', '열', '뽕', '붐'],
#              285: ['런닝맨', '수'],
#              286: ['부럽', '만족'],
#              287: ['얘기', '걱정', '대학', '궁금'],
#              288: ['단', '팬'],
#              290: ['이름', '혈', '혈액'],
#              291: ['병', '거 예쁜', '안에', '쓸', '윗', '공감 능', '학교 다닐 때는'],
#              292: ['틀어', '삼', '삼시', '10분 있'],
#              293: ['면'],
#              295: ['선수'],
#              297: ['날', '한라산', '갔던 곳 모두 좋았지만'],
#              298: ['장'],
#              299: ['내가 생', '안 보', '역'],
#              300: ['또 그러고', '의', '높', '받아'],
#              301: ['걷'],
#              302: ['한 살'],
#              303: ['난 아무래도', '학교 나가고'],
#              304: ['젊', '안 했으니까'],
#              305: ['애', '데', '안 할'],
#              306: ['강아지가 이', '주인이 무지하니까', '쉽지 않아'],
#              307: ['우리 아들', '응', '마오가 있으니까', '수술 하고 나서는'],
#              308: ['오리'],
#              309: ['장', '안', '닭도리'],
#              310: ['수요일'],
#              311: ['그냥 바로 포장하면은 냉장고에 다 넣어 놓고', '메'],
#              312: ['케이', '음악', '청소년'],
#              314: ['때', '훨', '협재'],
#              315: ['홈', '샀으니', '잔'],
#              316: ['운', '집이'],
#              317: ['제트'],
#              318: ['채', '멕시코 식당', '각시', '화덕피자'],
#              319: ['롤', '물류'],
#              320: ['코인'],
#              321: ['매년 정주행', '동백꽃'],
#              322: ['영화'],
#              323: ['온천'],
#              324: ['놀'],
#              325: ['운동'],
#              327: ['선', '얘기', '하자'],
#              328: ['기', '고용'],
#              329: ['방', '본원 통화', '선물', '경', '그렇게 보면', '상'],
#              330: ['수', '소형 평', '화', '돈 때문', '안 들', '네가 아까'],
#              331: ['한 분', '세 시간'],
#              332: ['쫄', '10000원', '두 명', '그런 거', '부모님들', '만'],
#              333: ['홈플러스', '스타필드'],
#              334: ['배달', '물품'],
#              335: ['추워지면 바로'],
#              336: ['초', '1년'],
#              337: ['맛있', '강릉', '계획'],
#              338: ['다른 군데 또 가고', '한 끼도', '운전에 너무'],
#              339: ['틀'],
#              342: ['의'],
#              343: ['힘들', '폰'],
#              344: ['그런 거', '일 잘', '거 그런', '1 2시'],
#              345: ['홈플러스 건너편', '구워 먹는 그런', '2 3명'],
#              346: ['번데기'],
#              347: ['중국', '좀 한번', '분', '정책', '테크', '상한', '어떤 큰'],
#              348: ['그런', '100만 원', '똑같', '잘못'],
#              349: ['내가 뭔', '주점', '걸어 보는 건'],
#              350: ['봐'],
#              351: ['삐끗'],
#              353: ['반'],
#              354: ['커', '캡'],
#              355: ['조금', '한 군데'],
#              361: ['있지 않나'],
#              362: ['만', '한남'],
#              364: ['식'],
#              365: ['만'],
#              367: ['접'],
#              368: ['여러 분야의 사람들도 만나보고 나랑 다른 친구들도 많이 사귀어보고'],
#              370: ['들었'],
#              371: ['요즘', '신나'],
#              372: ['도서관 중앙', '사케', '순댓국'],
#              373: ['비린 것도', '가성비', '고기류'],
#              375: ['육아'],
#              376: ['좋아하고 찌개'],
#              378: ['런닝맨', '짤막'],
#              379: ['가족이'],
#              380: ['뒤집어'],
#              382: ['한 달 이상은'],
#              383: ['그런 것들이 좀'],
#              384: ['멀리'],
#              385: ['좀 화', '드라'],
#              386: ['리메이크', '그분'],
#              387: ['의', '김광석 씨'],
#              388: ['많았'],
#              390: ['면접', '인터넷 뉴스 같은 데서는 저녁 7시에서 8시부터는 금식을 하라고'],
#              391: ['강박적'],
#              392: ['다시 한번', '여기 갔다가'],
#              393: ['경주', '맛있는 회', '가고 싶'],
#              394: ['모르', '행신'],
#              395: ['정도', '진', '찍'],
#              396: ['떡갈비'],
#              397: ['그래 그러면', '쑥 맛 아이스크림이랑'],
#              398: ['존경한'],
#              399: ['안', '안', '혹', '현미'],
#              400: ['의'],
#              403: ['전화로'],
#              404: ['100', '만', '중간', '있는', '양상추', '해 먹', '다이어트'],
#              407: ['의', '의', '돈도 돈이지만 가족처럼 해 줬을 때'],
#              409: ['외국', '희'],
#              410: ['투잡'],
#              412: ['아무', '3시 반'],
#              414: ['게', '게'],
#              416: ['개인', '채', '다이어트 할 때', '병행'],
#              417: ['근처',
#               '다이어트를 떠나서',
#               '뱃',
#               '땡',
#               '과일 같은 거는',
#               '사과',
#               '자기 모든 것이 딱',
#               '평안'],
#              419: ['때'],
#              423: ['손', '위험'],
#              430: ['게', '얻'],
#              431: ['에프', '비싸지', '타'],
#              432: ['과', '뽑', '기회비용'],
#              433: ['뽑', '어불'],
#              434: ['있으', '말', '친구', '의', 'name 씨', '절'],
#              435: ['정말 자연적으로 다'],
#              436: ['1장', '메롱'],
#              437: ['기'],
#              439: ['그때', '산책', '식단'],
#              440: ['수', '더러운 게 티가 잘 안 나고', '길'],
#              443: ['컸'],
#              444: ['저녁 때', '돈가스', '숯', '풀', '너 이럴'],
#              445: ['닭껍질', '내가 봤', '홍'],
#              446: ['이름'],
#              449: ['셔플'],
#              450: ['면', '보조 어떤'],
#              451: ['어디 구', '어디 동'],
#              456: ['고기', '사이에'],
#              457: ['쉴세 없이', '김'],
#              458: ['지난 8월 달에', '울렁', '배', '검은'],
#              461: ['팥'],
#              462: ['울부'],
#              463: ['동물'],
#              464: ['문어'],
#              465: ['일하는 스트레스', '부담스럽', '배려를 해 주면 좋은데 그게 어렵더라고'],
#              466: ['내가 유'],
#              467: ['나이', '발', '호텔 델루나', '드'],
#              468: ['외국', '새별오름', '풍경', '바다', '참돔', '해운대'],
#              469: ['분위', '그렇지 겨울 바다'],
#              471: ['카페', '큰 형님이'],
#              472: ['한국', '옷', '괌', '고래'],
#              474: ['엄', '쳐다보고 내렸다가', '유럽', '굴 농'],
#              475: ['아이', '샷'],
#              476: ['멀', '내려', '핸', '대면'],
#              478: ['2학년', '최저등', '강박', '취업', '만화책에'],
#              479: ['전기', '고리', '차', '보장'],
#              480: ['효', '한 번', '했었'],
#              482: ['빵'],
#              483: ['식', '딸기'],
#              484: ['딱', '귀엽'],
#              485: ['키우', '굉', '최근', 'name2'],
#              490: ['안', '염증', '묘'],
#              491: ['상'],
#              492: ['기', '하루'],
#              493: ['이 년', '안양'],
#              497: ['언덕', '경험'],
#              498: ['어떤 부분', '관'],
#              501: ['참치', '성게알'],
#              503: ['1해'],
#              505: ['두 병']})

# %%
dev_repeated_phrase_indices
# Out:
# defaultdict(list,
#             {0: ['자', '유산', '안 했'],
#              1: ['가', '고'],
#              2: ['음식을 먹으실 때'],
#              3: ['말'],
#              4: ['자', '평'],
#              5: ['찾게 되', '오랜만에 도가니', '건물 지어가지고', '인테리어'],
#              6: ['산', '능이', '자연', '식', '맛', '그런 게', '문', '비서'],
#              11: ['자', '가', '챙', '탈', '후', '고'],
#              12: ['설', '혹', '우리'],
#              13: ['가', '가', '고'],
#              14: ['가', '야간 알바'],
#              15: ['가', '치', '떡볶이', '그렇게 하면', '거기', '고'],
#              16: ['씁'],
#              17: ['가', '노', '저 돈', '네다', '라', '뭘 하려면'],
#              18: ['유산균이', '건강'],
#              20: ['마', '순간', '최근에 종영한'],
#              21: ['인', '요즘'],
#              22: ['최', '드라'],
#              23: ['실망도 하고'],
#              25: ['이름', '쓰이'],
#              26: ['입', '반려묘', '버', '개'],
#              27: ['가', '설', '약', '겨울', '습'],
#              28: ['가', '항', '무'],
#              30: ['가'],
#              31: ['최', '매'],
#              32: ['형'],
#              34: ['산', '가', '고'],
#              35: ['무', '갱년기가 오면서', '둘레길', '자전거'],
#              36: ['전', '튼튼하'],
#              37: ['말', '가', '입', '반'],
#              38: ['반', '반려', '못', '키'],
#              39: ['말', '자', '자', '가', '거 같은', '배', '고'],
#              40: ['주', '워'],
#              41: ['된', '한 번', '나'],
#              42: ['어떻게 보면은', '자녀들을 키우면서', '듣', '나'],
#              43: ['아이', '나', '나'],
#              44: ['가', '그래', '고'],
#              46: ['다녀왔는데 친구 집에', '하면', '가지'],
#              47: ['잠자', '애들'],
#              48: ['투 에어팟', '비합', '대학', '화', '나'],
#              49: ['가', '많', '뿌', '마라', '고', '고', '고'],
#              50: ['떡볶이', '굳', '보이'],
#              51: ['있으'],
#              52: ['2세', '그런 욕심', '안 되더라'],
#              53: ['인', '약', '표현', '엄'],
#              54: ['그래', '버거', '나랑 대화가 안', '이 사람하고'],
#              55: ['1학', '다음 학기', '수'],
#              56: ['도와주겠', '걔', '고'],
#              57: ['못', '단톡', '단', '압', '같고', '그랬는데', '시', '시'],
#              58: ['잠도 오고 그러니까', '체육'],
#              59: ['가', '가', '고', '고', '고', '고', '고'],
#              60: ['고', '고', '고', '여수', '그때'],
#              61: ['가', '빅', '홈'],
#              62: ['미국', '타', '일으', '우승'],
#              63: ['재'],
#              64: ['공', '그런 것들', '그거', '진', '상품', '해대'],
#              66: ['공', '생겨', '쌓'],
#              67: ['했'],
#              68: ['가', '가', '가', '결재를 받는'],
#              69: ['가', '많', '남자'],
#              70: ['정당하'],
#              71: ['가', '가', '고', '고', '열심히 해서'],
#              73: ['가',
#               '미국',
#               '캐니언이',
#               '그랜드 캐녀',
#               '문화',
#               '동부 쪽',
#               '작',
#               '옹고',
#               '고런 쪽',
#               '산호',
#               '나'],
#              74: ['제주도'],
#              75: ['가', '가', '주', '습'],
#              76: ['닮', '말이', '미'],
#              77: ['음식', '시', '굉'],
#              78: ['찾', '나'],
#              79: ['나'],
#              80: ['가', '가', '가', '가', '가'],
#              82: ['돈', '콜센'],
#              83: ['가', '잃', '잃'],
#              84: ['가', '가', '가', '무', '무', '고', '시'],
#              85: ['가', '너'],
#              86: ['오빠야', '결혼', '너희', '여', '골', '젊은'],
#              88: ['가', '한', '가야 되는데', '트 드'],
#              89: ['짜잘'],
#              90: ['고', '고'],
#              91: ['매'],
#              92: ['가'],
#              93: ['학교 생'],
#              94: ['꿈', '사진'],
#              95: ['가', '고'],
#              96: ['쿵쾅', '너무 배가 고파서'],
#              97: ['가족 끼리'],
#              100: ['주', '건'],
#              101: ['부', '추사랑', '내 친구', '예를 들', '즐기', '자기들 인생이기 때문에']})

# %%
test_repeated_phrase_indices
# Out:
# defaultdict(list,
#             {0: ['팥'],
#              4: ['중간', '고', '생일 날에'],
#              5: ['고', '매', '중학교 때는', '어렸을 때'],
#              6: ['고', '발음', '간호사'],
#              7: ['어색', '에', '남자', '티를 내야지', '아무런 징조도 없이', '저 사람이', '짜'],
#              8: ['매점에'],
#              10: ['야구를 했', '다르', '하게 됐', '꿈', '우선적으로', '그것'],
#              11: ['3 40', '도'],
#              13: ['우리 엄마'],
#              14: ['1위', '고'],
#              15: ['머리', '브'],
#              16: ['진', '잠', '품', '인간', '짧', '님', '키웠', '나무틀', '처음에'],
#              18: ['달', '고'],
#              19: ['유튜버 활', '도'],
#              20: ['거 그런'],
#              22: ['이성', '이성', '납', '시계'],
#              23: ['고'],
#              24: ['연애', '시국이', '굉', '통계'],
#              25: ['의', '무', '그랬'],
#              27: ['미술', '포토', '외국', '인지', '뇌'],
#              28: ['에'],
#              29: ['의'],
#              30: ['서'],
#              31: ['어떻게 하지', '층간'],
#              32: ['찍', '눈'],
#              34: ['신'],
#              35: ['봐'],
#              36: ['앞', '부모님'],
#              37: ['원', '박사', '교', '거래', '쓰러', '이야기해'],
#              38: ['서민', '스릴러'],
#              40: ['집에', '영화'],
#              43: ['무', '느', '오에스티들', '옛날 추', '드라', '이래', '이런', '보고 싶다는', '들'],
#              44: ['서'],
#              45: ['형', '끓이', '서'],
#              46: ['동', '자기'],
#              48: ['의', '힘'],
#              49: ['더워'],
#              50: ['예고'],
#              52: ['방성훈 씨'],
#              54: ['신', '말', '여러 가지', '누구', '그런 식'],
#              55: ['안 보', '치', '옛날 프로그램', '최신 프로'],
#              56: ['코', '도리', '요즘'],
#              57: ['결혼', '반려', '펼'],
#              58: ['돈', '무', '아직도', '도'],
#              61: ['체험', '부스'],
#              62: ['맛', '시간 제한', '간'],
#              64: ['아무'],
#              67: ['무', '요구', '서'],
#              69: ['무'],
#              70: ['무', '서'],
#              72: ['고'],
#              73: ['고', '화장'],
#              74: ['의', '이상'],
#              75: ['의'],
#              76: ['코팡'],
#              77: ['무', '죽기 전에', '찾아', '캐나다', '위험'],
#              78: ['서'],
#              79: ['게시'],
#              82: ['고', '로브스터'],
#              83: ['무', '드'],
#              84: ['고', '비가 오는', '키'],
#              85: ['무'],
#              87: ['중3 때', '줬'],
#              89: ['서'],
#              90: ['뛰'],
#              91: ['관'],
#              92: ['의', '서'],
#              94: ['이러잖', '축구', '그리'],
#              95: ['안 닿는'],
#              96: ['곤충', '햇빛', '다슬기', '있어', '장난', '서', '서'],
#              97: ['성격', '무서'],
#              98: ['고', '고', '교', '교', '교', '과학 시간', '매점', '급식은 약간'],
#              99: ['고', '님'],
#              100: ['고', '거예'],
#              102: ['올해', '서'],
#              103: ['남해'],
#              106: ['에'],
#              108: ['에'],
#              111: ['거기', '수월', '여수 말고는'],
#              112: ['화장실', '손 씻는', '시스템이었'],
#              113: ['육지에', '열었', '생각을 해 보고', '교통편'],
#              114: ['별'],
#              117: ['팔찌', '이렇게 하자'],
#              121: ['인', '고', '낳'],
#              122: ['인'],
#              123: ['수업'],
#              125: ['어색', '한 달'],
#              126: ['무', '본 거 또 보고'],
#              128: ['1', '반', '서'],
#              130: ['영화 잘'],
#              132: ['고', '양'],
#              133: ['요리 프로그램'],
#              134: ['서', '잘 안 먹'],
#              135: ['고', '고', '셨'],
#              136: ['고', '교', '반', '없었'],
#              138: ['서', '서', '제주도'],
#              139: ['앞', '예', '도와', '못 즐'],
#              140: ['찍', '고', '친구 관계에'],
#              141: ['진', '데레'],
#              142: ['같', '서'],
#              143: ['80'],
#              144: ['적', '치게 하면', '춘천부'],
#              145: ['인', '팬', '비', '들어', '무엇', '어린'],
#              147: ['씀씀이가 크기 때문에'],
#              148: ['결혼', '진짜 결혼', '자기 삶 조금', '걔네 부모님', '얼굴'],
#              149: ['걔', '중학교 3학', '생각'],
#              150: ['살았', '실망', '그날', '버스'],
#              151: ['어디가 좋다', '또 되고', '하기 싫으냐'],
#              153: ['여름', '오이', '애들', '가지'],
#              154: ['눈을 떴'],
#              155: ['드림'],
#              156: ['서'],
#              158: ['꽃'],
#              159: ['정 토끼'],
#              160: ['서', '애를 먹이는', '할아버지', '할머니'],
#              161: ['큰', '서'],
#              162: ['고', '고', '대충', '한 바퀴 뛰고 한 바퀴 걷고'],
#              164: ['잃는'],
#              165: ['돌아서면 밥', 'name1'],
#              167: ['무'],
#              168: ['에', '91', '넣어'],
#              169: ['내가 연애했을 때는'],
#              171: ['고', '잘 안 가르', '쌤', '책을 찾고 있었는데', '돌', '독'],
#              172: ['6학년 때', '합'],
#              173: ['고'],
#              174: ['고', '바', '나오'],
#              175: ['겨울', '계셨는'],
#              176: ['여섯 시'],
#              182: ['홀', '열', '이용'],
#              183: ['서'],
#              184: ['여동'],
#              185: ['늘 말'],
#              188: ['꼭 나가야', '10'],
#              189: ['고'],
#              190: ['이렇'],
#              191: ['있으신가', '가끔'],
#              192: ['고', '고', '무', '그때', '놓', '솔', '키우고 싶다고'],
#              193: ['치', '적'],
#              194: ['홍어', '잡채', '허', '한식', '엠비', '빵'],
#              195: ['고', '음식', '물', '골', '북어', '식'],
#              196: ['음식', '건', '건', '클로라', '약', '운'],
#              197: ['같', '단', '쌀', '벌렁', '질', '않으'],
#              198: ['의', '서'],
#              199: ['여동생'],
#              200: ['의', '의', '의지'],
#              201: ['누나', '었'],
#              202: ['30'],
#              204: ['고', '고', '고', '근', '쏘', '쏘'],
#              205: ['부분', '어떤 거'],
#              206: ['고', '무'],
#              207: ['계시', '정도'],
#              208: ['어리', '6', '찾'],
#              209: ['보니', '하나', '하셨', '두 개', '혹'],
#              210: ['자녀가 많다면', '들', '쪽'],
#              211: ['연락을 많이 하고'],
#              212: ['동', '돈', '드', '할 게', '쉬운 거', '가격', '잡아'],
#              213: ['아르',
#               '비디오테이프',
#               '대학교 1학년 때',
#               '아르바이트를 한 다음에 받은 돈으로',
#               '사용자 한테'],
#              214: ['고', '자기', '아무도 가르쳐주지 않으니까', '준', '듣', '그런 방식'],
#              216: ['팥'],
#              217: ['배우', '아니', '공유', '디즈', '센과 치히로', '센'],
#              218: ['판빙빙', '영화배우 중에', '톰 크루즈가'],
#              219: ['우리', '우리', '그것도 나쁘지', '치즈 닭갈비', '새벽', '뜨'],
#              222: ['단', '조금 많이', '부탁', '맞', '나머지 부위'],
#              223: ['선수', '팔꿈'],
#              225: ['아가씨'],
#              226: ['말', '고', '고', '무', '무', '몇 주', '쉬', '손', '액'],
#              227: ['나대고 싶어 하는 성'],
#              229: ['지나', '꺼낼 정도로', '예전에', '저랑 제일 가까운 사람'],
#              230: ['지지'],
#              231: ['의', '서'],
#              233: ['서', '둘째 날'],
#              234: ['전', '누비'],
#              235: ['운', '스키'],
#              236: ['에'],
#              237: ['했었'],
#              238: ['않', '상대', '상대방'],
#              239: ['고', '언', 'name1이', '이뤄'],
#              240: ['죽', '짜'],
#              241: ['에', '에', '물', '남', '또 금방', '씻었'],
#              243: ['아저씨로 나오는'],
#              245: ['올해'],
#              246: ['고', '폭염'],
#              247: ['잃', '법'],
#              249: ['의'],
#              250: ['들었',
#               '어렵',
#               '아저',
#               '느꼈',
#               '사람',
#               '사회생활',
#               '싫어하는 사',
#               '싫어하면 나를',
#               '도'],
#              251: ['왕따', '쪼끔 더'],
#              252: ['무', '케어', '돈이 모', '껍'],
#              253: ['인', '고', '부'],
#              254: ['서', '시절', '얘', '명'],
#              255: ['아르', '카페'],
#              256: ['빵'],
#              257: ['고', '항'],
#              258: ['직', '갔을 때', '4 5학년', '받았'],
#              260: ['원', '서', '인형을 좋아해서'],
#              263: ['도'],
#              264: ['서'],
#              265: ['인', '올'],
#              266: ['고', '차 주인이', '끊고 나서 울고'],
#              270: ['서', '서', '직업', '경포호'],
#              272: ['근'],
#              273: ['고', '주변에'],
#              274: ['제가 어릴 때'],
#              275: ['고'],
#              276: ['작'],
#              277: ['서', '오빠', '낯'],
#              279: ['배우', '복싱', '운동선수', '보셨'],
#              280: ['고', '고 별로'],
#              281: ['코', '무', '서', '서', '귀'],
#              282: ['예', '뭔', '입장에서', '컵'],
#              283: ['족발'],
#              284: ['아직', '같은 관광지', '가야지 어디'],
#              285: ['프라하라', '루', '사막', '봉사', '이외에', '몇 개', '숙', '도'],
#              286: ['아르바이트', '아르바이트', '서', '서', '서', '한 지금', '대학교 들어가서', '있지'],
#              287: ['힘', '에', '서', '이러이러 하'],
#              288: ['고', '서', '마련', '50'],
#              290: ['의'],
#              291: ['너무 이'],
#              292: ['중학교 때', '들'],
#              293: ['이 학', '강'],
#              294: ['에', '에', '들', '몇 퍼센트 이'],
#              295: ['고'],
#              296: ['근육 운동', '2프로'],
#              297: ['잘'],
#              298: ['말', '게', '한국', '이러한 상황'],
#              299: ['일이 있었'],
#              300: ['고', '날아', '체육'],
#              301: ['에', '퀴즈가 있었', '중국', '녹'],
#              302: ['보니', '옻', '칭'],
#              304: ['유튜버', '여자 연예인', '수지'],
#              305: ['오에', '그런 골목', '사건 풀어나가고', '나한테'],
#              306: ['유럽 여행', '100'],
#              307: ['낸', '낸', '계획', '60', '안전', '농', '또'],
#              308: ['고', '서'],
#              309: ['고'],
#              310: ['잠깐'],
#              311: ['어떻게 해야 되지', '두 명'],
#              313: ['점'],
#              314: ['빌', '평'],
#              316: ['고'],
#              318: ['고', '한 글자', '마니토', '뭔가 이벤트'],
#              319: ['정성'],
#              320: ['달', '고', '어렸', '달이'],
#              321: ['고', '무', '점', '수의'],
#              322: ['꼽', '제가 추천해 주고 싶은 여행지는'],
#              323: ['물놀이', '푸아그라'],
#              324: ['고', '서', '쪼금'],
#              326: ['눈이 간다'],
#              327: ['여름', '어디 있노', '문체'],
#              328: ['누가 봐도'],
#              329: ['그러다 보니까'],
#              330: ['1위', '고', '특히'],
#              331: ['에', '고', '이렇게 조금 더우'],
#              332: ['다 내리고 나서'],
#              333: ['하나', '영원히', '또 보고', '김보라 감독님'],
#              334: ['그런 영화들', '감독', '메기'],
#              335: ['살 빼고', '슬'],
#              337: ['술'],
#              339: ['고', '서', '불 떨어지'],
#              340: ['서', '어떤 병원은 이렇게 안 좋다더라'],
#              341: ['에', '고', '집에 왔을 때', '치우고 주고', '터치', '안 그래도'],
#              342: ['에',
#               '캐넌',
#               '드와이',
#               '팸',
#               '제일 좋은',
#               '너는 빅',
#               '쉘든',
#               '봤던 거 또 보고',
#               '나는 요새'],
#              343: ['올라와 보니', '위압', '승', '통'],
#              344: ['고1 들어오자마자', '열 시간', '차장', '다른 학교'],
#              345: ['평야', '목장'],
#              346: ['적응', '괌'],
#              347: ['고', '부', '좋아했던 거', '규격', '3', '골키퍼', '비인기 종목이다 보니까'],
#              348: ['고', '들어가고'],
#              350: ['고'],
#              351: ['구이', '흑'],
#              352: ['영상'],
#              353: ['서울', '무슨 더비', '무슨'],
#              354: ['짜'],
#              355: ['지나', '간'],
#              357: ['제가 지금', '선생님들이'],
#              358: ['하고 계', '분', '고등학교 와서 완전히'],
#              359: ['고'],
#              361: ['인'],
#              362: ['고'],
#              364: ['여행', '프랑스'],
#              365: ['무', '봤', '역'],
#              367: ['뒤처지'],
#              368: ['지금 항공', '뽑'],
#              369: ['연애', '안 보', '에', '의지', '차이', '잘 해주'],
#              370: ['서'],
#              371: ['고'],
#              373: ['생각만 해도', '돼', '갈비', '매일 먹어', '사다'],
#              375: ['서', '포스트잇', '비닐봉투'],
#              377: ['조', '소'],
#              378: ['말', '말', '에', '에', '질문'],
#              379: ['38년', '원했'],
#              380: ['자기', '자제'],
#              381: ['고', '그때쯤', '색깔이나 돌', '런', '안 좋겠'],
#              382: ['거기'],
#              383: ['햄스터', '병아리'],
#              384: ['고', '무', '보호소'],
#              385: ['중간', '고', '서', '넣'],
#              387: ['큰', '정'],
#              388: ['밥', '밥'],
#              389: ['에', '서'],
#              390: ['서'],
#              393: ['요기도 괜찮겠다'],
#              394: ['셋', '셋', '서', '끼', '자연', '보문사'],
#              395: ['한 해', '한 해', '쓰'],
#              396: ['않', '떠'],
#              398: ['고'],
#              399: ['에', '10000보'],
#              400: ['에', '도'],
#              401: ['맛'],
#              402: ['에', '여행', '서', '도', '군', '호주', '에메랄드'],
#              403: ['고'],
#              404: ['무', '도'],
#              405: ['중학교 때'],
#              406: ['고', '오대산', '자작나무숲', '래']})

# %%
# pickle로 저장
import pickle

with open('train_repeated_phrase_indices_0.pkl', 'wb') as f:
    pickle.dump(train_repeated_phrase_indices, f)

with open('dev_repeated_phrase_indices_0.pkl', 'wb') as f:
    pickle.dump(dev_repeated_phrase_indices, f)

with open('test_repeated_phrase_indices_0.pkl', 'wb') as f:
    pickle.dump(test_repeated_phrase_indices, f)

# %%
# pickle로 불러오기

with open('train_repeated_phrase_indices_0.pkl', 'rb') as f:
    train_repeated_phrase_indices = pickle.load(f)

with open('dev_repeated_phrase_indices_0.pkl', 'rb') as f:
    dev_repeated_phrase_indices = pickle.load(f)

with open('test_repeated_phrase_indices_0.pkl', 'rb') as f:
    test_repeated_phrase_indices = pickle.load(f)

# %%
def make_one_repeated_words(data:json, path:str, iter:int=0):
    """
    Replace the repeated words in the text with one word.

    Parameters:
    data (json): Data to be processed.
    path (str): Path to save the processed data.

    Returns:
    data (json): Processed data.
    """
    
    # Function for removing repeated words
    def removeing_repeated_words(data:json, repeated_phrase_indices:dict, mode:str):
        # repeated_phrase_indices = {key : index, value : repeated phrase}

        for idx in tqdm(repeated_phrase_indices.keys(), total=len(repeated_phrase_indices), desc=f'Removing repeated phrases in {mode} data ... (Phase {iter})'):
            repeated_phrases = repeated_phrase_indices[idx]
            for phrase in repeated_phrases:
                pattern = rf'{phrase} {phrase}'
                for i, turn in enumerate(data[idx]['input']['conversation']):
                    if re.search(pattern, turn['utterance']):
                        data[idx]['input']['conversation'][i]['utterance'] = re.sub(pattern, phrase, turn['utterance'])

    # Remove repeated words in the conversation
    if 'train' in path:
        with open(f'train_repeated_phrase_indices_{iter}.pkl', 'rb') as file:
            repeated_phrase_indices = pickle.load(file)
        
        removeing_repeated_words(data, repeated_phrase_indices, mode='train')

    elif 'dev' in path:
        with open(f'dev_repeated_phrase_indices_{iter}.pkl', 'rb') as file:
            repeated_phrase_indices = pickle.load(file)
        removeing_repeated_words(data, repeated_phrase_indices, mode='dev')

    elif 'test' in path:
        with open(f'test_repeated_phrase_indices_{iter}.pkl', 'rb') as file:
            repeated_phrase_indices = pickle.load(file)
        removeing_repeated_words(data, repeated_phrase_indices, mode='test')

    return data

# %%
# Read the json file
with open('./train.json', 'rb') as file:
        train_data = json.load(file)
with open('./dev.json', 'rb') as file:
        dev_data = json.load(file)
with open('./test.json', 'rb') as file:
        test_data = json.load(file)

post_train_data = make_one_repeated_words(train_data, 'train.json', iter=0)
post_dev_data = make_one_repeated_words(dev_data, 'dev.json', iter=0)
post_test_data = make_one_repeated_words(test_data, 'test.json', iter=0)
# Out:
# Removing repeated phrases in train data ... (Phase 0): 100%|██████████| 378/378 [00:00<00:00, 13502.70it/s]
# Removing repeated phrases in dev data ... (Phase 0): 100%|██████████| 87/87 [00:00<00:00, 12418.05it/s]
# Removing repeated phrases in test data ... (Phase 0): 100%|██████████| 313/313 [00:00<00:00, 16132.33it/s]

# %%
with open('./test_train.json', 'w') as file:
    json.dump(post_train_data, file, ensure_ascii=False, indent=4)

with open('./test_dev.json', 'w') as file:
    json.dump(post_dev_data, file, ensure_ascii=False, indent=4)

with open('./test_test.json', 'w') as file:
    json.dump(post_test_data, file, ensure_ascii=False, indent=4)

# %%
test_train = make_dataframe('./test_train.json')
test_dev = make_dataframe('./test_dev.json')
test_test = make_dataframe('./test_test.json')

# %%
test_train_idx, _ = find_repeated_phrases(test_train)
test_dev_idx, _ = find_repeated_phrases(test_dev)
test_test_idx, _ = find_repeated_phrases(test_test)
# Out:
# The number of repeated phrases in conversation : 89
# The number of repeated phrases in conversation that repeated num <= 2 : 13
# The number of repeated phrases in output : 2
# The number of repeated phrases in conversation : 15
# The number of repeated phrases in conversation that repeated num <= 2 : 1
# The number of repeated phrases in output : 1
# The number of repeated phrases in conversation : 73
# The number of repeated phrases in conversation that repeated num <= 2 : 8
# The number of repeated phrases in output : 0

# %%
test_train_idx
# Out:
# [('가', 62),
#  ('다', 29),
#  ('이', 28),
#  ('있', 26),
#  ('나', 22),
#  ('하', 21),
#  ('거', 13),
#  ('먹', 12),
#  ('내', 10),
#  ('없', 9),
#  ('사', 9),
#  ('너', 9),
#  ('해', 8),
#  ('저', 8),
#  ('유', 7),
#  ('대', 7),
#  ('시', 7),
#  ('요', 7),
#  ('일', 7),
#  ('그래', 6),
#  ('많', 6),
#  ('했', 6),
#  ('고', 6),
#  ('주', 6),
#  ('제', 5),
#  ('학', 5),
#  ('원', 5),
#  ('여', 5),
#  ('자', 5),
#  ('생', 5),
#  ('한', 5),
#  ('같', 4),
#  ('건', 4),
#  ('보', 4),
#  ('올', 4),
#  ('약', 4),
#  ('지', 4),
#  ('그렇', 4),
#  ('우', 4),
#  ('입', 4),
#  ('얼', 4),
#  ('매', 4),
#  ('거기', 4),
#  ('외', 4),
#  ('집', 4),
#  ('맞', 4),
#  ('않', 4),
#  ('되', 4),
#  ('우리', 4),
#  ('들', 3),
#  ('영', 3),
#  ('재료', 3),
#  ('그냥', 3),
#  ('엄마', 3),
#  ('재', 3),
#  ('몇', 3),
#  ('여름', 3),
#  ('세', 3),
#  ('중', 3),
#  ('인', 3),
#  ('별', 3),
#  ('강', 3),
#  ('3', 3),
#  ('한 명', 3),
#  ('언니', 3),
#  ('친', 3),
#  ('어디', 3),
#  ('신', 3),
#  ('마', 3),
#  ('쪼금', 3),
#  ('시국이', 3),
#  ('언', 3),
#  ('취', 3),
#  ('고양이', 3),
#  ('예', 3),
#  ('그거', 3),
#  ('났던', 1),
#  ('첫날', 1),
#  ('중에서 어떤 계절', 1),
#  ('습관', 1),
#  ('전단지', 1),
#  ('아줌마들이 구하', 1),
#  ('윗사람이랑', 1),
#  ('안 보인다', 1),
#  ('학교 나가고 집에 오고', 1),
#  ('맞아 온천도', 1),
#  ('화천', 1),
#  ('추워지면 바로', 1),
#  ('운전에 너무 힘들어서 다음 운전을 위해서', 1)]

# %%
train_repeated_phrase_indices2 = find_index_of_repeated_phrases(test_train,[c[0] for c in test_train_idx if c[1]<=2])
dev_repeated_phrase_indices2 = find_index_of_repeated_phrases(test_dev,[c[0] for c in test_dev_idx if c[1]<=2])
test_repeated_phrase_indices2 = find_index_of_repeated_phrases(test_test,[c[0] for c in test_test_idx if c[1]<=2])
# Out:
# 100%|██████████| 506/506 [00:00<00:00, 4474.53it/s]
# 100%|██████████| 102/102 [00:00<00:00, 20408.29it/s]
# 100%|██████████| 408/408 [00:00<00:00, 3916.20it/s]

# %%
train_repeated_phrase_indices2
# Out:
# defaultdict(list,
#             {2: ['났던'],
#              18: ['첫날'],
#              94: ['중에서 어떤 계절'],
#              155: ['습관'],
#              181: ['전단지'],
#              182: ['아줌마들이 구하'],
#              291: ['윗사람이랑'],
#              299: ['안 보인다'],
#              303: ['학교 나가고 집에 오고'],
#              323: ['맞아 온천도'],
#              330: ['화천'],
#              335: ['추워지면 바로'],
#              338: ['운전에 너무 힘들어서 다음 운전을 위해서']})

# %%
with open('train_repeated_phrase_indices_1.pkl', 'wb') as f:
    pickle.dump(train_repeated_phrase_indices2, f)

with open('dev_repeated_phrase_indices_1.pkl', 'wb') as f:
    pickle.dump(dev_repeated_phrase_indices2, f)

with open('test_repeated_phrase_indices_1.pkl', 'wb') as f:
    pickle.dump(test_repeated_phrase_indices2, f)

# %%
with open('test_train.json', 'rb') as f:
    test_train = json.load(f)
with open('test_dev.json', 'rb') as f:
    test_dev = json.load(f)
with open('test_test.json', 'rb') as f:
    test_test = json.load(f)

test_train_2 = make_one_repeated_words(test_train, 'test_train.json', iter=1)
test_dev_2 = make_one_repeated_words(test_dev, 'test_dev.json', iter=1)
test_test_2 = make_one_repeated_words(test_test, 'test_test.json', iter=1)
# Out:
# Removing repeated phrases in train data ... (Phase 1): 100%|██████████| 13/13 [00:00<00:00, 25173.57it/s]
# Removing repeated phrases in dev data ... (Phase 1): 100%|██████████| 1/1 [00:00<?, ?it/s]
# Removing repeated phrases in test data ... (Phase 1): 100%|██████████| 8/8 [00:00<00:00, 7998.67it/s]

# %%
with open('./test_train2.json', 'w') as file:
    json.dump(test_train_2, file, ensure_ascii=False, indent=4)

with open('./test_dev2.json', 'w') as file:
    json.dump(test_dev_2, file, ensure_ascii=False, indent=4)

with open('./test_test2.json', 'w') as file:
    json.dump(test_test_2, file, ensure_ascii=False, indent=4)

# %%
test_train3 = make_dataframe('./test_train2.json')
test_dev3 = make_dataframe('./test_dev2.json')
test_test3 = make_dataframe('./test_test2.json')

# %%
test_train_idx3, _ = find_repeated_phrases(test_train3)
test_dev_idx3, _ = find_repeated_phrases(test_dev3)
test_test_idx3, _ = find_repeated_phrases(test_test3)
# Out:
# The number of repeated phrases in conversation : 76
# The number of repeated phrases in conversation that repeated num <= 2 : 0
# The number of repeated phrases in output : 2
# The number of repeated phrases in conversation : 14
# The number of repeated phrases in conversation that repeated num <= 2 : 0
# The number of repeated phrases in output : 1
# The number of repeated phrases in conversation : 65
# The number of repeated phrases in conversation that repeated num <= 2 : 0
# The number of repeated phrases in output : 0

# %%
# 후처리 이후
t = make_dataframe('./train.json')
d = make_dataframe('./dev.json')
te = make_dataframe('./test.json')

_, _ = find_repeated_phrases(t)
_, _ = find_repeated_phrases(d)
_, _ = find_repeated_phrases(te)
# Out:
# The number of repeated phrases in conversation : 76
# The number of repeated phrases in conversation that repeated num <= 2 : 0
# The number of repeated phrases in output : 2
# The number of repeated phrases in conversation : 14
# The number of repeated phrases in conversation that repeated num <= 2 : 0
# The number of repeated phrases in output : 1
# The number of repeated phrases in conversation : 65
# The number of repeated phrases in conversation that repeated num <= 2 : 0
# The number of repeated phrases in output : 0

# %% [markdown]
# <br/>
#
# <br/>

# %%
import re

# 자음과 모음의 범위를 지정합니다.
consonant = "[ㄱ-ㅎ]"
vowel = "[ㅏ-ㅣ]"

# 같은 자음이 두 번 사용된 음절을 포착하는 정규식
pattern = f"({consonant})({vowel}) \1({vowel})"

# 매칭을 테스트합니다.
word = "겨 계절"
match = re.search(pattern, word)

if match:
    print("패턴이 일치합니다:", match.group())
else:
    print("패턴이 일치하지 않습니다.")
# Out:
# 패턴이 일치하지 않습니다.

# %%
# !pip install jamo
# Out:
# Collecting jamo
#   Obtaining dependency information for jamo from https://files.pythonhosted.org/packages/ac/cc/49812faae67f9a24be6ddaf58a2cf7e8c3cbfcf5b762d9414f7103d2ea2c/jamo-0.4.1-py3-none-any.whl.metadata
#   Downloading jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Installing collected packages: jamo
# Successfully installed jamo-0.4.1

# %%
from jamo import h2j, j2hcj
from unicode import join_jamos
from collections import defaultdict

def find_matching_syllables(word):
    # 한글 음절을 자소(자음, 모음)로 분리합니다.
    decomposed = [j2hcj(h2j(syllable)) for syllable in word if syllable != ' ']
    
    temp = defaultdict(int)
    # 자음이 같은 음절 쌍을 찾습니다.
    for i in range(len(decomposed) - 1):
        first = decomposed[i]
        second = decomposed[i + 1]
        
        # 자음(첫 번째 자모)이 같은지 확인
        if first[0] == second[0]:
            temp[(join_jamos(first)+' '+ join_jamos(second))]+=1
    
    return temp

# 테스트
word = "겨 계절"
find_matching_syllables(word)
# Out:
# defaultdict(int, {'겨 계': 1})
